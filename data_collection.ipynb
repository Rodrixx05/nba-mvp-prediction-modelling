# %% [markdown]
# <a href="https://colab.research.google.com/github/Rodrixx05/nba-mvp-prediction-modelling/blob/master/data_collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install unidecode
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 4.0 MB/s eta 0:00:00
# ...

# %%
import os
project_folder = '/content/drive/MyDrive/nba-project'
os.chdir(project_folder)
pickles_folder = os.path.join(os.getcwd(), 'datasets')
os.getcwd()
# Out:
# '/content/drive/MyDrive/nba-project'

# %%
import pandas as pd
import custom_modules.basketball_reference_rodrixx as brr

# %%
stats_df = pd.read_pickle(os.path.join(pickles_folder, 'stats_1982_to_2022.pkl'))

# %%
getter = brr.BasketballReferenceGetter()

# %%
stats_df_2023 = getter.extract_player_stats_multiple(2023, mvp = True, advanced = True, ranks = True)
# Out:
# /content/drive/MyDrive/nba-project/custom_modules/basketball_reference_rodrixx.py:276: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_return['%G'] = round(df_return['G'] / df_return ['GT'], 3)

# %%
stats_df_2023.head()
# Out:
#    Rk            Player Pos  Age   Tm   G  GS  MP_pg  FG_pg  FGA_pg  ...  \
# 0   1  Precious Achiuwa   C   23  TOR  55  12   20.7    3.6     7.3  ...
# 1   2      Steven Adams   C   29  MEM  42  42   27.0    3.7     6.3  ...
# 2   3       Bam Adebayo   C   25  MIA  75  75   34.6    8.0    14.9  ...
# 3   4      Ochai Agbaji  SG   22  UTA  59  22   20.5    2.8     6.5  ...
# 4   5      Santi Aldama  PF   22  MEM  77  20   21.8    3.2     6.8  ...
#
#    DBPM_rank  BPM_rank  VORP_rank     %W  GT  %W_rank     %G  Votes  Share  \
# 0         51        91         49  0.500  82       34  0.671      0    0.0
# 1         34        62         41  0.622  82        7  0.512      0    0.0
# 2         35        53         25  0.537  82       24  0.915      0    0.0
# 3         57        98         51  0.451  82       52  0.720      0    0.0
# 4         35        63         37  0.622  82        7  0.939      0    0.0
#
#    MaxVotes
# 0      1000
# 1      1000
# 2      1000
# 3      1000
# ...

# %%
stats_df_2023.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 679 entries, 0 to 678
# Data columns (total 138 columns):
#  #    Column        Dtype
# ---   ------        -----
#  0    Rk            int64
#  1    Player        object
#  2    Pos           object
#  3    Age           int64
#  4    Tm            object
#  5    G             int64
#  6    GS            int64
#  7    MP_pg         float64
#  8    FG_pg         float64
#  9    FGA_pg        float64
#  10   FG%           float64
#  11   3P_pg         float64
#  12   3PA_pg        float64
#  13   3P%           float64
#  14   2P_pg         float64
#  15   2PA_pg        float64
#  16   2P%           float64
#  17   eFG%          float64
#  18   FT_pg         float64
#  19   FTA_pg        float64
#  20   FT%           float64
#  21   ORB_pg        float64
#  22   DRB_pg        float64
#  23   TRB_pg        float64
#  24   AST_pg        float64
#  25   STL_pg        float64
#  26   BLK_pg        float64
#  27   TOV_pg        float64
# ...

# %%
stats_df_2023[stats_df_2023['Share'] > 0]
# Out:
#       Rk                   Player Pos  Age   Tm   G  GS  MP_pg  FG_pg  FGA_pg  \
# 12    11    Giannis Antetokounmpo  PF   28  MIL  63  63   32.1   11.2    20.3
# 92    69            Jalen Brunson  PG   26  NYK  68  68   35.0    8.6    17.6
# 100   75             Jimmy Butler  PF   33  MIA  64  64   33.4    7.5    13.9
# 139  108            Stephen Curry  PG   34  GSW  56  56   34.7   10.0    20.2
# 160  125              Luka Dončić  PG   23  DAL  66  66   36.2   10.9    22.0
# 184  143              Joel Embiid   C   28  PHI  66  66   34.6   11.0    20.1
# 198  153             De'Aaron Fox  PG   25  SAC  73  73   33.4    9.3    18.2
# 209  164  Shai Gilgeous-Alexander  PG   24  OKC  68  68   35.5   10.4    20.3
# 318  249             Nikola Jokić   C   27  DEN  69  69   33.7    9.4    14.8
# 427  338         Donovan Mitchell  SG   26  CLE  68  68   35.8   10.0    20.6
# 435  346                Ja Morant  PG   23  MEM  61  59   31.9    9.3    19.9
# ...

# %%
stats_df = pd.concat([stats_df, stats_df_2023], ignore_index = True)

# %%
stats_df.to_pickle(os.path.join(pickles_folder, 'stats_1982_to_2023.pkl'))
