# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install unidecode
# Out:
# Collecting unidecode
#   Downloading Unidecode-1.3.8-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 4.8 MB/s eta 0:00:00
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.8

# %%
import os
project_folder = '/content/drive/MyDrive/nba-project'
os.chdir(project_folder)
pickles_folder = os.path.join(os.getcwd(), 'datasets')
os.getcwd()
# Out:
# '/content/drive/MyDrive/nba-project'

# %%
import pandas as pd
import custom_modules.basketball_reference_rodrixx as brr

# %%
year_extract = 2024

# %%
stats_df_hist = pd.read_pickle(os.path.join(pickles_folder, f'stats_1982_to_{year_extract - 1}.pkl'))

# %%
getter = brr.BasketballReferenceGetter()

# %%
stats_df_current = getter.extract_player_stats_multiple(year_extract, mvp = True, advanced = True, ranks = True)
# Out:
# /content/drive/MyDrive/nba-project/custom_modules/basketball_reference_rodrixx.py:276: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_return['%G'] = round(df_return['G'] / df_return ['GT'], 3)

# %%
stats_df_current.head()
# Out:
#    Rk            Player   Pos  Age   Tm   G  GS  MP_pg  FG_pg  FGA_pg  ...  \
# 0   1  Precious Achiuwa  PF-C   24  TOT  74  18   21.9    3.2     6.3  ...
# 1   1  Precious Achiuwa     C   24  TOR  25   0   17.5    3.1     6.8  ...
# 2   1  Precious Achiuwa    PF   24  NYK  49  18   24.2    3.2     6.1  ...
# 3   2       Bam Adebayo     C   26  MIA  71  71   34.0    7.5    14.3  ...
# 4   3      Ochai Agbaji    SG   23  TOT  78  28   21.0    2.3     5.6  ...
#
#    DBPM_rank  BPM_rank  VORP_rank     %W  GT  %W_rank     %G  Votes  Share  \
# 0         45        79         50  0.507  82       29  0.902      0    0.0
# 1         50        81         52  0.305  82       75  0.305      0    0.0
# 2         43        79         50  0.610  82        9  0.598      0    0.0
# 3         31        41         25  0.561  82       21  0.866      0    0.0
# 4         57       109         62  0.353  82       63  0.951      0    0.0
#
#    MaxVotes
# 0       990
# 1       990
# 2       990
# 3       990
# 4       990
#
# [5 rows x 138 columns]

# %%
stats_df_current.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 735 entries, 0 to 734
# Data columns (total 138 columns):
#  #    Column        Dtype
# ---   ------        -----
#  0    Rk            int64
#  1    Player        object
#  2    Pos           object
#  3    Age           int64
#  4    Tm            object
#  5    G             int64
#  6    GS            int64
#  7    MP_pg         float64
#  8    FG_pg         float64
#  9    FGA_pg        float64
#  10   FG%           float64
#  11   3P_pg         float64
#  12   3PA_pg        float64
#  13   3P%           float64
#  14   2P_pg         float64
#  15   2PA_pg        float64
#  16   2P%           float64
#  17   eFG%          float64
#  18   FT_pg         float64
#  19   FTA_pg        float64
#  20   FT%           float64
#  21   ORB_pg        float64
#  22   DRB_pg        float64
#  23   TRB_pg        float64
#  24   AST_pg        float64
#  25   STL_pg        float64
#  26   BLK_pg        float64
#  27   TOV_pg        float64
#  28   PF_pg         float64
#  29   PTS_pg        float64
#  30   MP_rank_pg    int64
#  31   FG_rank_pg    int64
#  32   FGA_rank_pg   int64
#  33   FG%_rank      int64
#  34   3P_rank_pg    int64
#  35   3PA_rank_pg   int64
#  36   3P%_rank      int64
#  37   2P_rank_pg    int64
#  38   2PA_rank_pg   int64
#  39   2P%_rank      int64
#  40   eFG%_rank     int64
#  41   FT_rank_pg    int64
#  42   FTA_rank_pg   int64
#  43   FT%_rank      int64
#  44   ORB_rank_pg   int64
#  45   DRB_rank_pg   int64
#  46   TRB_rank_pg   int64
#  47   AST_rank_pg   int64
#  48   STL_rank_pg   int64
#  49   BLK_rank_pg   int64
#  50   TOV_rank_pg   int64
#  51   PF_rank_pg    int64
#  52   PTS_rank_pg   int64
#  53   %GS           float64
#  54   Season        int64
#  55   MP_tot        int64
#  56   FG_tot        int64
#  57   FGA_tot       int64
#  58   3P_tot        int64
#  59   3PA_tot       int64
#  60   2P_tot        int64
#  61   2PA_tot       int64
#  62   FT_tot        int64
#  63   FTA_tot       int64
#  64   ORB_tot       int64
#  65   DRB_tot       int64
#  66   TRB_tot       int64
#  67   AST_tot       int64
#  68   STL_tot       int64
#  69   BLK_tot       int64
#  70   TOV_tot       int64
#  71   PF_tot        int64
#  72   PTS_tot       int64
#  73   MP_rank_tot   int64
#  74   FG_rank_tot   int64
#  75   FGA_rank_tot  int64
#  76   3P_rank_tot   int64
#  77   3PA_rank_tot  int64
#  78   2P_rank_tot   int64
#  79   2PA_rank_tot  int64
#  80   FT_rank_tot   int64
#  81   FTA_rank_tot  int64
#  82   ORB_rank_tot  int64
#  83   DRB_rank_tot  int64
#  84   TRB_rank_tot  int64
#  85   AST_rank_tot  int64
#  86   STL_rank_tot  int64
#  87   BLK_rank_tot  int64
#  88   TOV_rank_tot  int64
#  89   PF_rank_tot   int64
#  90   PTS_rank_tot  int64
#  91   PER           float64
#  92   TS%           float64
#  93   3PAr          float64
#  94   FTr           float64
#  95   ORB%          float64
#  96   DRB%          float64
#  97   TRB%          float64
#  98   AST%          float64
#  99   STL%          float64
#  100  BLK%          float64
#  101  TOV%          float64
#  102  USG%          float64
#  103  OWS           float64
#  104  DWS           float64
#  105  WS            float64
#  106  WS/48         float64
#  107  OBPM          float64
#  108  DBPM          float64
#  109  BPM           float64
#  110  VORP          float64
#  111  PER_rank      int64
#  112  TS%_rank      int64
#  113  3PAr_rank     int64
#  114  FTr_rank      int64
#  115  ORB%_rank     int64
#  116  DRB%_rank     int64
#  117  TRB%_rank     int64
#  118  AST%_rank     int64
#  119  STL%_rank     int64
#  120  BLK%_rank     int64
#  121  TOV%_rank     int64
#  122  USG%_rank     int64
#  123  OWS_rank      int64
#  124  DWS_rank      int64
#  125  WS_rank       int64
#  126  WS/48_rank    int64
#  127  OBPM_rank     int64
#  128  DBPM_rank     int64
#  129  BPM_rank      int64
#  130  VORP_rank     int64
#  131  %W            float64
#  132  GT            int64
#  133  %W_rank       int64
#  134  %G            float64
#  135  Votes         int64
#  136  Share         float64
#  137  MaxVotes      int64
# dtypes: float64(47), int64(88), object(3)
# memory usage: 792.5+ KB

# %%
stats_df_current[stats_df_current['Share'] > 0]
# Out:
#       Rk                   Player Pos  Age   Tm   G  GS  MP_pg  FG_pg  FGA_pg  \
# 14    11    Giannis Antetokounmpo  PF   29  MIL  73  73   35.2   11.5    18.8
# 109   76            Jalen Brunson  PG   27  NYK  77  77   35.4   10.3    21.4
# 171  128            Luka DonÄiÄ  PG   24  DAL  70  70   37.5   11.5    23.6
# 180  137             Kevin Durant  PF   35  PHO  75  75   37.2   10.0    19.1
# 183  140          Anthony Edwards  SG   22  MIN  79  78   35.1    9.1    19.7
# 235  172  Shai Gilgeous-Alexander  PG   25  OKC  75  75   34.0   10.6    19.8
# 340  263            Nikola JokiÄ   C   28  DEN  79  79   34.6   10.4    17.9
# 577  444         Domantas Sabonis   C   27  SAC  82  82   35.7    7.7    13.0
# 630  489             Jayson Tatum  PF   25  BOS  74  74   35.7    9.1    19.3
#
#      ...  DBPM_rank  BPM_rank  VORP_rank     %W  GT  %W_rank     %G  Votes  \
# 14   ...         24         9          3  0.598  82       10  0.890    192
# 109  ...         52        15          6  0.610  82        9  0.939    142
# 171  ...         31         6          2  0.610  82        9  0.854    566
# 180  ...         47        26         12  0.598  82       10  0.915      1
# 183  ...         43        32         15  0.683  82        3  0.963     18
# 235  ...         25         9          4  0.695  82        2  0.915    640
# 340  ...         11         4          1  0.695  82        2  0.963    926
# 577  ...         24        13          5  0.561  82       21  1.000      3
# 630  ...         42        20          9  0.780  82        1  0.902     86
#
#      Share  MaxVotes
# 14   0.194       990
# 109  0.143       990
# 171  0.572       990
# 180  0.001       990
# 183  0.018       990
# 235  0.646       990
# 340  0.935       990
# 577  0.003       990
# 630  0.087       990
#
# [9 rows x 138 columns]

# %%
stats_df = pd.concat([stats_df_hist, stats_df_current], ignore_index = True)

# %%
stats_df.to_pickle(os.path.join(pickles_folder, f'stats_1982_to_{year_extract}.pkl'))
