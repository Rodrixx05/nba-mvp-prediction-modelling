# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install cloudscraper
# Out:
# Requirement already satisfied: cloudscraper in /usr/local/lib/python3.12/dist-packages (1.2.71)
# Requirement already satisfied: pyparsing>=2.4.7 in /usr/local/lib/python3.12/dist-packages (from cloudscraper) (3.2.5)
# Requirement already satisfied: requests>=2.9.2 in /usr/local/lib/python3.12/dist-packages (from cloudscraper) (2.32.4)
# Requirement already satisfied: requests-toolbelt>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from cloudscraper) (1.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.9.2->cloudscraper) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.9.2->cloudscraper) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.9.2->cloudscraper) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.9.2->cloudscraper) (2025.10.5)

# %%
import os
project_folder = '/content/drive/MyDrive/nba-project'
os.chdir(project_folder)
pickles_folder = os.path.join(os.getcwd(), 'datasets')
os.getcwd()
# Out:
# '/content/drive/MyDrive/nba-project'

# %%
import pandas as pd
import custom_modules.basketball_reference_rodrixx as brr
# Out:
# /content/drive/MyDrive/nba-project/custom_modules/basketball_reference_rodrixx.py:134: SyntaxWarning: invalid escape sequence '\d'
#   df_player_stats_pg['Tm'] = df_player_stats_pg['Tm'].replace(to_replace = '\dTM', value = 'TOT', regex = True)
# /content/drive/MyDrive/nba-project/custom_modules/basketball_reference_rodrixx.py:179: SyntaxWarning: invalid escape sequence '\d'
#   df_player_stats_totals['Tm'] = df_player_stats_totals['Tm'].replace(to_replace = '\dTM', value = 'TOT', regex = True)
# /content/drive/MyDrive/nba-project/custom_modules/basketball_reference_rodrixx.py:222: SyntaxWarning: invalid escape sequence '\d'
#   df_player_stats_advanced['Tm'] = df_player_stats_advanced['Tm'].replace(to_replace = '\dTM', value = 'TOT', regex = True)

# %%
year_extract = 2025

# %%
stats_df_hist = pd.read_pickle(os.path.join(pickles_folder, f'stats_1982_to_{year_extract - 1}.pkl'))

# %%
getter = brr.BasketballReferenceGetter()

# %%
stats_df_current = getter.extract_player_stats_multiple(year_extract, totals = True, mvp = True, team_stats = True)

# %%
stats_df_current.head()
# Out:
#                     Player  Age   Tm Pos   G  GS  MP_pg  FG_pg  FGA_pg    FG%  \
# 0  Shai Gilgeous-Alexander   26  OKC  PG  76  76   34.2   11.3    21.8  0.519
# 1    Giannis Antetokounmpo   30  MIL  PF  67  67   34.2   11.8    19.7  0.601
# 2             Nikola Jokić   29  DEN   C  70  70   36.7   11.2    19.5  0.576
# 3              Luka Dončić   25  TOT  PG  50  50   35.4    9.2    20.5  0.450
# 4              Luka Dončić   25  DAL  PG  22  22   35.7    9.8    21.2  0.464
#
#    ...  TOV_tot  PF_tot  PTS_tot  Trp-Dbl     %W  GT     %G  Votes  Share  \
# 0  ...      183     164     2484        0  0.829  82  0.927    913  0.913
# 1  ...      206     155     2036       11  0.585  82  0.817    470  0.470
# 2  ...      230     160     2071       34  0.610  82  0.854    787  0.787
# 3  ...      179     126     1408        5  0.551  82  0.610      0  0.000
# 4  ...       75      58      619        3  0.476  82  0.268      0  0.000
#
#    MaxVotes
# 0      1000
# 1      1000
# 2      1000
# 3      1000
# 4      1000
#
# [5 rows x 56 columns]

# %%
stats_df_current.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 735 entries, 0 to 734
# Data columns (total 56 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Player    735 non-null    object
#  1   Age       735 non-null    int64
#  2   Tm        735 non-null    object
#  3   Pos       735 non-null    object
#  4   G         735 non-null    int64
#  5   GS        735 non-null    int64
#  6   MP_pg     735 non-null    float64
#  7   FG_pg     735 non-null    float64
#  8   FGA_pg    735 non-null    float64
#  9   FG%       735 non-null    float64
#  10  3P_pg     735 non-null    float64
#  11  3PA_pg    735 non-null    float64
#  12  3P%       735 non-null    float64
#  13  2P_pg     735 non-null    float64
#  14  2PA_pg    735 non-null    float64
#  15  2P%       735 non-null    float64
#  16  eFG%      735 non-null    float64
#  17  FT_pg     735 non-null    float64
#  18  FTA_pg    735 non-null    float64
#  19  FT%       735 non-null    float64
#  20  ORB_pg    735 non-null    float64
#  21  DRB_pg    735 non-null    float64
#  22  TRB_pg    735 non-null    float64
#  23  AST_pg    735 non-null    float64
#  24  STL_pg    735 non-null    float64
#  25  BLK_pg    735 non-null    float64
#  26  TOV_pg    735 non-null    float64
#  27  PF_pg     735 non-null    float64
#  28  PTS_pg    735 non-null    float64
#  29  %GS       735 non-null    float64
#  30  Season    735 non-null    int64
#  31  MP_tot    735 non-null    int64
#  32  FG_tot    735 non-null    int64
#  33  FGA_tot   735 non-null    int64
#  34  3P_tot    735 non-null    int64
#  35  3PA_tot   735 non-null    int64
#  36  2P_tot    735 non-null    int64
#  37  2PA_tot   735 non-null    int64
#  38  FT_tot    735 non-null    int64
#  39  FTA_tot   735 non-null    int64
#  40  ORB_tot   735 non-null    int64
#  41  DRB_tot   735 non-null    int64
#  42  TRB_tot   735 non-null    int64
#  43  AST_tot   735 non-null    int64
#  44  STL_tot   735 non-null    int64
#  45  BLK_tot   735 non-null    int64
#  46  TOV_tot   735 non-null    int64
#  47  PF_tot    735 non-null    int64
#  48  PTS_tot   735 non-null    int64
#  49  Trp-Dbl   735 non-null    int64
#  50  %W        735 non-null    float64
#  51  GT        735 non-null    int64
#  52  %G        735 non-null    float64
#  53  Votes     735 non-null    int64
#  54  Share     735 non-null    float64
#  55  MaxVotes  735 non-null    int64
# dtypes: float64(27), int64(26), object(3)
# memory usage: 321.7+ KB

# %%
stats_df_current[stats_df_current['Share'] > 0]
# Out:
#                      Player  Age   Tm Pos   G  GS  MP_pg  FG_pg  FGA_pg  \
# 0   Shai Gilgeous-Alexander   26  OKC  PG  76  76   34.2   11.3    21.8
# 1     Giannis Antetokounmpo   30  MIL  PF  67  67   34.2   11.8    19.7
# 2              Nikola Jokić   29  DEN   C  70  70   36.7   11.2    19.5
# 6           Anthony Edwards   23  MIN  SG  79  79   36.3    9.1    20.4
# 7              Jayson Tatum   26  BOS  PF  72  72   36.4    9.2    20.3
# 10          Cade Cunningham   23  DET  PG  70  70   35.0    9.8    20.8
# 11            Jalen Brunson   28  NYK  PG  65  65   35.4    9.0    18.5
# 21            Stephen Curry   36  GSW  PG  70  70   32.2    8.1    18.0
# 22             LeBron James   40  LAL  SF  70  70   34.9    9.3    18.1
# 27         Donovan Mitchell   28  CLE  SG  71  71   31.4    8.2    18.6
# 38             James Harden   35  LAC  PG  79  79   35.3    6.7    16.4
# 70              Evan Mobley   23  CLE  PF  71  71   30.5    7.1    12.8
#
#       FG%  ...  TOV_tot  PF_tot  PTS_tot  Trp-Dbl     %W  GT     %G  Votes  \
# 0   0.519  ...      183     164     2484        0  0.829  82  0.927    913
# 1   0.601  ...      206     155     2036       11  0.585  82  0.817    470
# 2   0.576  ...      230     160     2071       34  0.610  82  0.854    787
# 6   0.447  ...      249     150     2177        0  0.598  82  0.963     12
# 7   0.452  ...      209     157     1932        2  0.744  82  0.878    311
# 10  0.469  ...      309     195     1830        9  0.537  82  0.854     12
# 11  0.488  ...      164     138     1690        0  0.622  82  0.793      1
# 21  0.448  ...      200      95     1718        0  0.585  82  0.854      2
# 22  0.513  ...      260      99     1710       10  0.610  82  0.854     16
# 27  0.443  ...      149     140     1701        0  0.780  82  0.866     74
# 38  0.410  ...      341     162     1802        3  0.610  82  0.963      1
# 70  0.557  ...      145     141     1316        0  0.780  82  0.866      1
#
#     Share  MaxVotes
# 0   0.913      1000
# 1   0.470      1000
# 2   0.787      1000
# 6   0.012      1000
# 7   0.311      1000
# 10  0.012      1000
# 11  0.001      1000
# 21  0.002      1000
# 22  0.016      1000
# 27  0.074      1000
# 38  0.001      1000
# 70  0.001      1000
#
# [12 rows x 56 columns]

# %%
stats_df = pd.concat([stats_df_hist, stats_df_current], ignore_index = True)

# %%
stats_df.to_pickle(os.path.join(pickles_folder, f'stats_1982_to_{year_extract}.pkl'))
