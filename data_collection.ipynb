# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pandas.__version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-068244f7ed4b> in <cell line: 1>()
# ----> 1 pandas.__version__
#
# NameError: name 'pandas' is not defined

# %%
import os
project_folder = '/content/drive/MyDrive/nba-project'
os.chdir(project_folder)
pickles_folder = os.path.join(os.getcwd(), 'datasets')
os.getcwd()
# Out:
# '/content/drive/MyDrive/nba-project'

# %%
import pandas as pd
import custom_modules.basketball_reference_rodrixx as brr

# %%
year_extract = 2024

# %%
stats_df_hist = pd.read_pickle(os.path.join(pickles_folder, f'stats_1982_to_{year_extract - 1}.pkl'))

# %%
getter = brr.BasketballReferenceGetter()

# %%
stats_df_current = getter.extract_player_stats_multiple(year_extract, mvp = True, advanced = True, ranks = True)

# %%
stats_df_current.head()
# Out:
#                     Player  Age   Tm Pos   G  GS  MP_pg  FG_pg  FGA_pg    FG%  \
# 0              Joel Embiid   29  PHI   C  39  39   33.6   11.5    21.8  0.529
# 1              Luka Dončić   24  DAL  PG  70  70   37.5   11.5    23.6  0.487
# 2    Giannis Antetokounmpo   29  MIL  PF  73  73   35.2   11.5    18.8  0.611
# 3  Shai Gilgeous-Alexander   25  OKC  PG  75  75   34.0   10.6    19.8  0.535
# 4            Jalen Brunson   27  NYK  PG  77  77   35.4   10.3    21.4  0.479
#
#    ...  DBPM_rank  BPM_rank  VORP_rank     %W  GT  %W_rank     %G  Votes  \
# 0  ...         18         5         10  0.573  82       16  0.476      0
# 1  ...         31         6          2  0.610  82        8  0.854      0
# 2  ...         24         9          3  0.598  82        9  0.890    192
# 3  ...         25         9          4  0.695  82        2  0.915    640
# 4  ...         52        15          6  0.610  82        8  0.939    142
#
#    Share  MaxVotes
# 0  0.000       990
# 1  0.000       990
# 2  0.194       990
# 3  0.646       990
# 4  0.143       990
#
# [5 rows x 137 columns]

# %%
stats_df_current.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 722 entries, 0 to 721
# Data columns (total 137 columns):
#  #    Column        Dtype
# ---   ------        -----
#  0    Player        object
#  1    Age           int64
#  2    Tm            object
#  3    Pos           object
#  4    G             int64
#  5    GS            int64
#  6    MP_pg         float64
#  7    FG_pg         float64
#  8    FGA_pg        float64
#  9    FG%           float64
#  10   3P_pg         float64
#  11   3PA_pg        float64
#  12   3P%           float64
#  13   2P_pg         float64
#  14   2PA_pg        float64
#  15   2P%           float64
#  16   eFG%          float64
#  17   FT_pg         float64
#  18   FTA_pg        float64
#  19   FT%           float64
#  20   ORB_pg        float64
#  21   DRB_pg        float64
#  22   TRB_pg        float64
#  23   AST_pg        float64
#  24   STL_pg        float64
#  25   BLK_pg        float64
#  26   TOV_pg        float64
#  27   PF_pg         float64
#  28   PTS_pg        float64
#  29   MP_rank_pg    int64
#  30   FG_rank_pg    int64
#  31   FGA_rank_pg   int64
#  32   FG%_rank      int64
#  33   3P_rank_pg    int64
#  34   3PA_rank_pg   int64
#  35   3P%_rank      int64
#  36   2P_rank_pg    int64
#  37   2PA_rank_pg   int64
#  38   2P%_rank      int64
#  39   eFG%_rank     int64
#  40   FT_rank_pg    int64
#  41   FTA_rank_pg   int64
#  42   FT%_rank      int64
#  43   ORB_rank_pg   int64
#  44   DRB_rank_pg   int64
#  45   TRB_rank_pg   int64
#  46   AST_rank_pg   int64
#  47   STL_rank_pg   int64
#  48   BLK_rank_pg   int64
#  49   TOV_rank_pg   int64
#  50   PF_rank_pg    int64
#  51   PTS_rank_pg   int64
#  52   %GS           float64
#  53   Season        int64
#  54   MP_tot        int64
#  55   FG_tot        int64
#  56   FGA_tot       int64
#  57   3P_tot        int64
#  58   3PA_tot       int64
#  59   2P_tot        int64
#  60   2PA_tot       int64
#  61   FT_tot        int64
#  62   FTA_tot       int64
#  63   ORB_tot       int64
#  64   DRB_tot       int64
#  65   TRB_tot       int64
#  66   AST_tot       int64
#  67   STL_tot       int64
#  68   BLK_tot       int64
#  69   TOV_tot       int64
#  70   PF_tot        int64
#  71   PTS_tot       int64
#  72   MP_rank_tot   int64
#  73   FG_rank_tot   int64
#  74   FGA_rank_tot  int64
#  75   3P_rank_tot   int64
#  76   3PA_rank_tot  int64
#  77   2P_rank_tot   int64
#  78   2PA_rank_tot  int64
#  79   FT_rank_tot   int64
#  80   FTA_rank_tot  int64
#  81   ORB_rank_tot  int64
#  82   DRB_rank_tot  int64
#  83   TRB_rank_tot  int64
#  84   AST_rank_tot  int64
#  85   STL_rank_tot  int64
#  86   BLK_rank_tot  int64
#  87   TOV_rank_tot  int64
#  88   PF_rank_tot   int64
#  89   PTS_rank_tot  int64
#  90   PER           float64
#  91   TS%           float64
#  92   3PAr          float64
#  93   FTr           float64
#  94   ORB%          float64
#  95   DRB%          float64
#  96   TRB%          float64
#  97   AST%          float64
#  98   STL%          float64
#  99   BLK%          float64
#  100  TOV%          float64
#  101  USG%          float64
#  102  OWS           float64
#  103  DWS           float64
#  104  WS            float64
#  105  WS/48         float64
#  106  OBPM          float64
#  107  DBPM          float64
#  108  BPM           float64
#  109  VORP          float64
#  110  PER_rank      int64
#  111  TS%_rank      int64
#  112  3PAr_rank     int64
#  113  FTr_rank      int64
#  114  ORB%_rank     int64
#  115  DRB%_rank     int64
#  116  TRB%_rank     int64
#  117  AST%_rank     int64
#  118  STL%_rank     int64
#  119  BLK%_rank     int64
#  120  TOV%_rank     int64
#  121  USG%_rank     int64
#  122  OWS_rank      int64
#  123  DWS_rank      int64
#  124  WS_rank       int64
#  125  WS/48_rank    int64
#  126  OBPM_rank     int64
#  127  DBPM_rank     int64
#  128  BPM_rank      int64
#  129  VORP_rank     int64
#  130  %W            float64
#  131  GT            int64
#  132  %W_rank       int64
#  133  %G            float64
#  134  Votes         int64
#  135  Share         float64
#  136  MaxVotes      int64
# dtypes: float64(47), int64(87), object(3)
# memory usage: 772.9+ KB

# %%
stats_df_current[stats_df_current['Share'] > 0]
# Out:
#                      Player  Age   Tm Pos   G  GS  MP_pg  FG_pg  FGA_pg  \
# 2     Giannis Antetokounmpo   29  MIL  PF  73  73   35.2   11.5    18.8
# 3   Shai Gilgeous-Alexander   25  OKC  PG  75  75   34.0   10.6    19.8
# 4             Jalen Brunson   27  NYK  PG  77  77   35.4   10.3    21.4
# 6              Kevin Durant   35  PHO  PF  75  75   37.2   10.0    19.1
# 7              Jayson Tatum   25  BOS  PF  74  74   35.7    9.1    19.3
# 12          Anthony Edwards   22  MIN  SG  79  78   35.1    9.1    19.7
# 62         Domantas Sabonis   27  SAC   C  82  82   35.7    7.7    13.0
#
#       FG%  ...  DBPM_rank  BPM_rank  VORP_rank     %W  GT  %W_rank     %G  \
# 2   0.611  ...         24         9          3  0.598  82        9  0.890
# 3   0.535  ...         25         9          4  0.695  82        2  0.915
# 4   0.479  ...         52        15          6  0.610  82        8  0.939
# 6   0.523  ...         47        26         12  0.598  82        9  0.915
# 7   0.471  ...         42        20          9  0.780  82        1  0.902
# 12  0.461  ...         43        32         15  0.683  82        3  0.963
# 62  0.594  ...         24        13          5  0.561  82       19  1.000
#
#     Votes  Share  MaxVotes
# 2     192  0.194       990
# 3     640  0.646       990
# 4     142  0.143       990
# 6       1  0.001       990
# 7      86  0.087       990
# 12     18  0.018       990
# 62      3  0.003       990
#
# [7 rows x 137 columns]

# %%
stats_df = pd.concat([stats_df_hist.drop(columns = 'Rk'), stats_df_current], ignore_index = True)

# %%
stats_df.to_pickle(os.path.join(pickles_folder, f'stats_1982_to_{year_extract}.pkl'))
