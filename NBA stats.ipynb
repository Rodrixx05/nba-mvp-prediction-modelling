# %%
from nba_api.stats.endpoints import leaguedashplayerstats as stats
from nba_api.stats.static import players
from nba_api.stats.library.parameters import SeasonType
from unidecode import unidecode
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
# Constants

const_stats_object_kwargs = {
    'last_n_games': 0, 
    'per_mode_detailed': 'PerGame', 
    'season_type_all_star': SeasonType.regular, 
    'measure_type_detailed_defense': 'Base'
}

const_stats_columns_to_drop = ['NICKNAME','GP','W', 'L', 'W_PCT', 'MIN', 'FGM', 'FGA', \
                                'FG3A', 'FTA', 'FTM', 'DREB', 'PF', 'L_RANK', 'FGM_RANK', \
                                'FGA_RANK', 'FG3A_RANK', 'FTM_RANK', 'FTA_RANK', 'NBA_FANTASY_PTS', \
                               'NBA_FANTASY_PTS_RANK', 'CFID', 'CFPARAMS']

years = list(range(1996, 2022))
season_years = []
for pos in range(len(years) - 1):
    season_year = str(years[pos]) + '-' + str(years[pos + 1])[2:]
    season_years.append(season_year)

# %%
# Functions

def extract_mvp_votes(years):
    
    mvp_votes_by_season = {}
    
    for year in years:
        url = f'https://www.basketball-reference.com/awards/awards_{year}.html#mvp'
        response = requests.get(url)
        if response.status_code != 200:
            return response.status_code
        
        soup = BeautifulSoup(response.text)
        table_body = soup.find('table', {'id': 'mvp'}).find('tbody')
        rows = table_body.find_all('tr')

        mvp_votes = []
        for row in rows:
            player_data = []
            player = row.find('td').find('a').text
            player_data.append(player)
            votes = row.find('td', {'data-stat': 'points_won'}).text
            player_data.append(int(float(votes)))
            percentage = row.find('td', {'data-stat': 'award_share'}).text
            player_data.append(float(percentage))
            mvp_votes.append(player_data)
            
        mvp_votes_by_season[year] = pd.DataFrame(mvp_votes, columns = ['PLAYER', 'VOTES', 'VOTES_PCT'])
    
    return mvp_votes_by_season

def find_player_id(player):
    
    player_list = players.find_players_by_full_name(f'^{player}$')
    
    if len(player_list) == 0:
        return np.nan
    
    elif len(player_list) == 1:
        return player_list[0]['id']
    
    else:
        ids = []
        for player in player_list:
            ids.append(player['id'])
        return min(ids)

def steve_smith(df):
    df.loc[df[df['PLAYER'] == 'Steve Smith'].index, 'PLAYER_ID'] = 120

# %%
mvp_years = years[1:]

# %%
mvp_votes_stats_seasons = extract_mvp_votes(mvp_years)

# %%
for year in mvp_votes_stats_seasons:
    mvp_votes_stats_seasons[year]['PLAYER'] = mvp_votes_stats_seasons[year]['PLAYER'].apply(unidecode)
    mvp_votes_stats_seasons[year]['PLAYER_ID'] = mvp_votes_stats_seasons[year]['PLAYER'].apply(find_player_id)
    mvp_votes_stats_seasons[year]['PLAYER_ID'].fillna(120, inplace = True)
    mvp_votes_stats_seasons[year]['PLAYER_ID'] = mvp_votes_stats_seasons[year]['PLAYER_ID'].astype(int)
    print(mvp_votes_stats_seasons[year])
# Out:
#               PLAYER  VOTES  VOTES_PCT  PLAYER_ID
# 
# 5             Luka Doncic     42      0.042    1629029
# 6          Damian Lillard     38      0.038     203081
# 7           Julius Randle     20      0.020     203944
# 8            Derrick Rose     10      0.010     201565
# 9             Rudy Gobert      8      0.008     203497
# 10      Russell Westbrook      5      0.005     201566
# 11            Ben Simmons      3      0.003    1627732
# 12           James Harden      1      0.001     201935
# 13           LeBron James      1      0.001       2544
# 14          Kawhi Leonard      1      0.001     202695

# %%
stats_dfs_by_season = {}
for season in season_years:
    stats_df = stats.LeagueDashPlayerStats(**const_stats_object_kwargs, season = season).get_data_frames()[0]
    stats_df.drop(columns = const_stats_columns_to_drop, inplace = True)
    stats_df.dropna(inplace = True)
    stats_df['AGE'] = stats_df['AGE'].astype(int)
    stats_dfs_by_season[season] = stats_df

# %%
for season in stats_dfs_by_season:
    print(f'Season: {season}')
    print(stats_dfs_by_season[season].info())
    print(f'Null values: {stats_dfs_by_season[season].isnull().sum().sum()}')
    print('\n---------------------------\n')
# Out:
# Season: 1996-97
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 4 to 444
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PLAYER_ID          441 non-null    int64
#  1   PLAYER_NAME        441 non-null    object
#  2   TEAM_ID            441 non-null    float64
#  3   TEAM_ABBREVIATION  441 non-null    object
#  4   AGE                441 non-null    int32
#  5   FG_PCT             441 non-null    float64
#  6   FG3M               441 non-null    float64
#  7   FG3_PCT            441 non-null    float64
#  8   FT_PCT             441 non-null    float64
#  9   OREB               441 non-null    float64
#  10  REB                441 non-null    float64
#  11  AST                441 non-null    float64
#  12  TOV                441 non-null    float64
#  13  STL                441 non-null    float64
#  14  BLK                441 non-null    float64
#  15  BLKA               441 non-null    float64
#  16  PFD                441 non-null    float64
#  17  PTS                441 non-null    float64
#  18  PLUS_MINUS         441 non-null    float64
#  19  DD2                441 non-null    int64
#  20  TD3                441 non-null    int64
#  21  GP_RANK            441 non-null    int64
#  22  W_RANK             441 non-null    int64
#  23  W_PCT_RANK         441 non-null    int64
#  24  MIN_RANK           441 non-null    int64
#  25  FG_PCT_RANK        441 non-null    int64
#  26  FG3M_RANK          441 non-null    int64
#  27  FG3_PCT_RANK       441 non-null    int64
#  28  FT_PCT_RANK        441 non-null    int64
#  29  OREB_RANK          441 non-null    int64
#  30  DREB_RANK          441 non-null    int64
#  31  REB_RANK           441 non-null    int64
#  32  AST_RANK           441 non-null    int64
#  33  TOV_RANK           441 non-null    int64
#  34  STL_RANK           441 non-null    int64
#  35  BLK_RANK           441 non-null    int64
#  36  BLKA_RANK          441 non-null    int64
#  37  PF_RANK            441 non-null    int64
#  38  PFD_RANK           441 non-null    int64
#  39  PTS_RANK           441 non-null    int64
#  40  PLUS_MINUS_RANK    441 non-null    int64
#  41  DD2_RANK           441 non-null    int64
#  42  TD3_RANK           441 non-null    int64
# dtypes: float64(15), int32(1), int64(25), object(2)
# memory usage: 149.9+ KB
# None
# Null values: 0
#
# ---------------------------
#
# Season: 1997-98
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 439 entries, 3 to 441
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PLAYER_ID          439 non-null    int64
#  1   PLAYER_NAME        439 non-null    object
#  2   TEAM_ID            439 non-null    float64
#  3   TEAM_ABBREVIATION  439 non-null    object
#  4   AGE                439 non-null    int32
#  5   FG_PCT             439 non-null    float64
#  6   FG3M               439 non-null    float64
#  7   FG3_PCT            439 non-null    float64
#  8   FT_PCT             439 non-null    float64
#  9   OREB               439 non-null    float64
#  10  REB                439 non-null    float64
#  11  AST                439 non-null    float64
#  12  TOV                439 non-null    float64
#  13  STL                439 non-null    float64
#  14  BLK                439 non-null    float64
#  15  BLKA               439 non-null    float64
#  16  PFD                439 non-null    float64
#  17  PTS                439 non-null    float64
#  18  PLUS_MINUS         439 non-null    float64
#  19  DD2                439 non-null    int64
#  20  TD3                439 non-null    int64
#  21  GP_RANK            439 non-null    int64
#  22  W_RANK             439 non-null    int64
#  23  W_PCT_RANK         439 non-null    int64
#  24  MIN_RANK           439 non-null    int64
#  25  FG_PCT_RANK        439 non-null    int64
#  26  FG3M_RANK          439 non-null    int64
#  27  FG3_PCT_RANK       439 non-null    int64
#  28  FT_PCT_RANK        439 non-null    int64
#  29  OREB_RANK          439 non-null    int64
#  30  DREB_RANK          439 non-null    int64
#  31  REB_RANK           439 non-null    int64
#  32  AST_RANK           439 non-null    int64
#  33  TOV_RANK           439 non-null    int64
#  34  STL_RANK           439 non-null    int64
#  35  BLK_RANK           439 non-null    int64
#  36  BLKA_RANK          439 non-null    int64
#  37  PF_RANK            439 non-null    int64
#  38  PFD_RANK           439 non-null    int64
#  39  PTS_RANK           439 non-null    int64
#  40  PLUS_MINUS_RANK    439 non-null    int64
#  41  DD2_RANK           439 non-null    int64
#  42  TD3_RANK           439 non-null    int64
# dtypes: float64(15), int32(1), int64(25), object(2)
# memory usage: 149.2+ KB
# None
# Null values: 0
#
# ---------------------------
#
# Season: 1998-99
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 440 entries, 0 to 439
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PLAYER_ID          440 non-null    int64
#  1   PLAYER_NAME        440 non-null    object
#  2   TEAM_ID            440 non-null    int64
#  3   TEAM_ABBREVIATION  440 non-null    object
#  4   AGE                440 non-null    int32
#  5   FG_PCT             440 non-null    float64
#  6   FG3M               440 non-null    float64
#  7   FG3_PCT            440 non-null    float64
#  8   FT_PCT             440 non-null    float64
#  9   OREB               440 non-null    float64
#  10  REB                440 non-null    float64
#  11  AST                440 non-null    float64
#  12  TOV                440 non-null    float64
#  13  STL                440 non-null    float64
#  14  BLK                440 non-null    float64
#  15  BLKA               440 non-null    float64
#  16  PFD                440 non-null    float64
#  17  PTS                440 non-null    float64
#  18  PLUS_MINUS         440 non-null    float64
#  19  DD2                440 non-null    int64
#  20  TD3                440 non-null    int64
#  21  GP_RANK            440 non-null    int64
#  22  W_RANK             440 non-null    int64
#  23  W_PCT_RANK         440 non-null    int64
#  24  MIN_RANK           440 non-null    int64
#  25  FG_PCT_RANK        440 non-null    int64
#  26  FG3M_RANK          440 non-null    int64
#  27  FG3_PCT_RANK       440 non-null    int64
#  28  FT_PCT_RANK        440 non-null    int64
#  29  OREB_RANK          440 non-null    int64
#  30  DREB_RANK          440 non-null    int64
#  31  REB_RANK           440 non-null    int64
#  32  AST_RANK           440 non-null    int64
#  33  TOV_RANK           440 non-null    int64
#  34  STL_RANK           440 non-null    int64
#  35  BLK_RANK           440 non-null    int64
#  36  BLKA_RANK          440 non-null    int64
#  37  PF_RANK            440 non-null    int64
#  38  PFD_RANK           440 non-null    int64
#  39  PTS_RANK           440 non-null    int64
#  40  PLUS_MINUS_RANK    440 non-null    int64
#  41  DD2_RANK           440 non-null    int64
#  42  TD3_RANK           440 non-null    int64
# dtypes: float64(14), int32(1), int64(26), object(2)
# memory usage: 149.5+ KB
# None
# Null values: 0
#
# ---------------------------
#
# Season: 1999-00
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 439 entries, 0 to 438
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PLAYER_ID          439 non-null    int64
#  1   PLAYER_NAME        439 non-null    object
#  2   TEAM_ID            439 non-null    int64
#  3   TEAM_ABBREVIATION  439 non-null    object
#  4   AGE                439 non-null    int32
#  5   FG_PCT             439 non-null    float64
#  6   FG3M               439 non-null    float64
#  7   FG3_PCT            439 non-null    float64
#  8   FT_PCT             439 non-null    float64
#  9   OREB               439 non-null    float64
#  10  REB                439 non-null    float64
#  11  AST                439 non-null    float64
#  12  TOV                439 non-null    float64
#  13  STL                439 non-null    float64
#  14  BLK                439 non-null    float64
#  15  BLKA               439 non-null    float64
#  16  PFD                439 non-null    float64
#  17  PTS                439 non-null    float64
#  18  PLUS_MINUS         439 non-null    float64
#  19  DD2                439 non-null    int64
#  20  TD3                439 non-null    int64
#  21  GP_RANK            439 non-null    int64
#  22  W_RANK             439 non-null    int64
#  23  W_PCT_RANK         439 non-null    int64
#  24  MIN_RANK           439 non-null    int64
#  25  FG_PCT_RANK        439 non-null    int64
#  26  FG3M_RANK          439 non-null    int64
#  27  FG3_PCT_RANK       439 non-null    int64
#  28  FT_PCT_RANK        439 non-null    int64
#  29  OREB_RANK          439 non-null    int64
#  30  DREB_RANK          439 non-null    int64
#  31  REB_RANK           439 non-null    int64
#  32  AST_RANK           439 non-null    int64
#  33  TOV_RANK           439 non-null    int64
#  34  STL_RANK           439 non-null    int64
#  35  BLK_RANK           439 non-null    int64
#  36  BLKA_RANK          439 non-null    int64
#  37  PF_RANK            439 non-null    int64
#  38  PFD_RANK           439 non-null    int64
#  39  PTS_RANK           439 non-null    int64
#  40  PLUS_MINUS_RANK    439 non-null    int64
#  41  DD2_RANK           439 non-null    int64
#  42  TD3_RANK           439 non-null    int64
# dtypes: float64(14), int32(1), int64(26), object(2)
# memory usage: 149.2+ KB
# None
# Null values: 0
#
# ---------------------------
#
# Season: 2000-01
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 440
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PLAYER_ID          441 non-null    int64
#  1   PLAYER_NAME        441 non-null    object
#  2   TEAM_ID            441 non-null    int64
#  3   TEAM_ABBREVIATION  441 non-null    object
#  4   AGE                441 non-null    int32
#  5   FG_PCT             441 non-null    float64
#  6   FG3M               441 non-null    float64
#  7   FG3_PCT            441 non-null    float64
#  8   FT_PCT             441 non-null    float64
#  9   OREB               441 non-null    float64
#  10  REB                441 non-null    float64
#  11  AST                441 non-null    float64
#  12  TOV                441 non-null    float64
#  13  STL                441 non-null    float64
#  14  BLK                441 non-null    float64
#  15  BLKA               441 non-null    float64
#  16  PFD                441 non-null    float64
#  17  PTS                441 non-null    float64
#  18  PLUS_MINUS         441 non-null    float64
#  19  DD2                441 non-null    int64
#  20  TD3                441 non-null    int64
#  21  GP_RANK            441 non-null    int64
#  22  W_RANK             441 non-null    int64
#  23  W_PCT_RANK         441 non-null    int64
#  24  MIN_RANK           441 non-null    int64
#  25  FG_PCT_RANK        441 non-null    int64
#  26  FG3M_RANK          441 non-null    int64
#  27  FG3_PCT_RANK       441 non-null    int64
#  28  FT_PCT_RANK        441 non-null    int64
#  29  OREB_RANK          441 non-null    int64
#  30  DREB_RANK          441 non-null    int64
#  31  REB_RANK           441 non-null    int64
#  32  AST_RANK           441 non-null    int64
#  33  TOV_RANK           441 non-null    int64
#  34  STL_RANK           441 non-null    int64
#  35  BLK_RANK           441 non-null    int64
#  36  BLKA_RANK          441 non-null    int64
#  37  PF_RANK            441 non-null    int64
#  38  PFD_RANK           441 non-null    int64
#  39  PTS_RANK           441 non-null    int64
#  40  PLUS_MINUS_RANK    441 non-null    int64
#  41  DD2_RANK           441 non-null    int64
#  42  TD3_RANK           441 non-null    int64
# dtypes: float64(14), int32(1), int64(26), object(2)
# memory usage: 149.9+ KB
# None
# Null values: 0
#
# ---------------------------
#
# Season: 2001-02
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 440 entries, 0 to 439
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PLAYER_ID          440 non-null    int64
#  1   PLAYER_NAME        440 non-null    object
#  2   TEAM_ID            440 non-null    int64
#  3   TEAM_ABBREVIATION  440 non-null    object
#  4   AGE                440 non-null    int32
#  5   FG_PCT             440 non-null    float64
#  6   FG3M               440 non-null    float64
#  7   FG3_PCT            440 non-null    float64
#  8   FT_PCT             440 non-null    float64
#  9   OREB               440 non-null    float64
#  10  REB                440 non-null    float64
#  11  AST                440 non-null    float64
#  12  TOV                440 non-null    float64
#  13  STL                440 non-null    float64
#  14  BLK                440 non-null    float64
#  15  BLKA               440 non-null    float64
#  16  PFD                440 non-null    float64
#  17  PTS                440 non-null    float64
#  18  PLUS_MINUS         440 non-null    float64
#  19  DD2                440 non-null    int64
#  20  TD3                440 non-null    int64
#  21  GP_RANK            440 non-null    int64
#  22  W_RANK             440 non-null    int64
#  23  W_PCT_RANK         440 non-null    int64
#  24  MIN_RANK           440 non-null    int64
#  25  FG_PCT_RANK        440 non-null    int64
#  26  FG3M_RANK          440 non-null    int64
#  27  FG3_PCT_RANK       440 non-null    int64
#  28  FT_PCT_RANK        440 non-null    int64
#  29  OREB_RANK          440 non-null    int64
#  30  DREB_RANK          440 non-null    int64
#  31  REB_RANK           440 non-null    int64
#  32  AST_RANK           440 non-null    int64
#  33  TOV_RANK           440 non-null    int64
#  34  STL_RANK           440 non-null    int64
#  35  BLK_RANK           440 non-null    int64
#  36  BLKA_RANK          440 non-null    int64
#  37  PF_RANK            440 non-null    int64
#  38  PFD_RANK           440 non-null    int64
#  39  PTS_RANK           440 non-null    int64
#  40  PLUS_MINUS_RANK    440 non-null    int64
#  41  DD2_RANK           440 non-null    int64
#  42  TD3_RANK           440 non-null    int64
# dtypes: float64(14), int32(1), int64(26), object(2)
# memory usage: 149.5+ KB
# None
# Null values: 0
#
# ---------------------------
#
# Season: 2002-03
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 428 entries, 0 to 427
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PLAYER_ID          428 non-null    int64
#  1   PLAYER_NAME        428 non-null    object
#  2   TEAM_ID            428 non-null    int64
#  3   TEAM_ABBREVIATION  428 non-null    object
#  4   AGE                428 non-null    int32
#  5   FG_PCT             428 non-null    float64
#  6   FG3M               428 non-null    float64
#  7   FG3_PCT            428 non-null    float64
#  8   FT_PCT             428 non-null    float64
#  9   OREB               428 non-null    float64
#  10  REB                428 non-null    float64
#  11  AST                428 non-null    float64
#  12  TOV                428 non-null    float64
#  13  STL                428 non-null    float64
#  14  BLK                428 non-null    float64
#  15  BLKA               428 non-null    float64
#  16  PFD                428 non-null    float64
#  17  PTS                428 non-null    float64
#  18  PLUS_MINUS         428 non-null    float64
#  19  DD2                428 non-null    int64
#  20  TD3                428 non-null    int64
#  21  GP_RANK            428 non-null    int64
#  22  W_RANK             428 non-null    int64
#  23  W_PCT_RANK         428 non-null    int64
#  24  MIN_RANK           428 non-null    int64
#  25  FG_PCT_RANK        428 non-null    int64
#  26  FG3M_RANK          428 non-null    int64
#  27  FG3_PCT_RANK       428 non-null    int64
#  28  FT_PCT_RANK        428 non-null    int64
#  29  OREB_RANK          428 non-null    int64
#  30  DREB_RANK          428 non-null    int64
#  31  REB_RANK           428 non-null    int64
#  32  AST_RANK           428 non-null    int64
#  33  TOV_RANK           428 non-null    int64
#  34  STL_RANK           428 non-null    int64
#  35  BLK_RANK           428 non-null    int64
#  36  BLKA_RANK          428 non-null    int64
#  37  PF_RANK            428 non-null    int64
#  38  PFD_RANK           428 non-null    int64
#  39  PTS_RANK           428 non-null    int64
#  40  PLUS_MINUS_RANK    428 non-null    int64
#  41  DD2_RANK           428 non-null    int64
#  42  TD3_RANK           428 non-null    int64
# dtypes: float64(14), int32(1), int64(26), object(2)
# memory usage: 145.5+ KB
# None
# Null values: 0
#
# ---------------------------
#
# Season: 2003-04
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 442 entries, 0 to 441
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PLAYER_ID          442 non-null    int64
#  1   PLAYER_NAME        442 non-null    object
#  2   TEAM_ID            442 non-null    int64
#  3   TEAM_ABBREVIATION  442 non-null    object
#  4   AGE                442 non-null    int32
#  5   FG_PCT             442 non-null    float64
#  6   FG3M               442 non-null    float64
#  7   FG3_PCT            442 non-null    float64
#  8   FT_PCT             442 non-null    float64
#  9   OREB               442 non-null    float64
#  10  REB                442 non-null    float64
#  11  AST                442 non-null    float64
#  12  TOV                442 non-null    float64
#  13  STL                442 non-null    float64
#  14  BLK                442 non-null    float64
#  15  BLKA               442 non-null    float64
#  16  PFD                442 non-null    float64
#  17  PTS                442 non-null    float64
#  18  PLUS_MINUS         442 non-null    float64
#  19  DD2                442 non-null    int64
#  20  TD3                442 non-null    int64
#  21  GP_RANK            442 non-null    int64
#  22  W_RANK             442 non-null    int64
#  23  W_PCT_RANK         442 non-null    int64
#  24  MIN_RANK           442 non-null    int64
#  25  FG_PCT_RANK        442 non-null    int64
#  26  FG3M_RANK          442 non-null    int64
#  27  FG3_PCT_RANK       442 non-null    int64
#  28  FT_PCT_RANK        442 non-null    int64
#  29  OREB_RANK          442 non-null    int64
#  30  DREB_RANK          442 non-null    int64
#  31  REB_RANK           442 non-null    int64
#  32  AST_RANK           442 non-null    int64
#  33  TOV_RANK           442 non-null    int64
#  34  STL_RANK           442 non-null    int64
#  35  BLK_RANK           442 non-null    int64
#  36  BLKA_RANK          442 non-null    int64
#  37  PF_RANK            442 non-null    int64
#  38  PFD_RANK           442 non-null    int64
#  39  PTS_RANK           442 non-null    int64
#  40  PLUS_MINUS_RANK    442 non-null    int64
#  41  DD2_RANK           442 non-null    int64
#  42  TD3_RANK           442 non-null    int64
# dtypes: float64(14), int32(1), int64(26), object(2)
# memory usage: 150.2+ KB
# None
# Null values: 0
#
# ---------------------------
#
# Season: 2004-05
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 464 entries, 0 to 463
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PLAYER_ID          464 non-null    int64
#  1   PLAYER_NAME        464 non-null    object
#  2   TEAM_ID            464 non-null    int64
#  3   TEAM_ABBREVIATION  464 non-null    object
#  4   AGE                464 non-null    int32
#  5   FG_PCT             464 non-null    float64
#  6   FG3M               464 non-null    float64
#  7   FG3_PCT            464 non-null    float64
#  8   FT_PCT             464 non-null    float64
#  9   OREB               464 non-null    float64
#  10  REB                464 non-null    float64
#  11  AST                464 non-null    float64
#  12  TOV                464 non-null    float64
#  13  STL                464 non-null    float64
#  14  BLK                464 non-null    float64
#  15  BLKA               464 non-null    float64
#  16  PFD                464 non-null    float64
#  17  PTS                464 non-null    float64
#  18  PLUS_MINUS         464 non-null    float64
#  19  DD2                464 non-null    int64
#  20  TD3                464 non-null    int64
#  21  GP_RANK            464 non-null    int64
#  22  W_RANK             464 non-null    int64
#  23  W_PCT_RANK         464 non-null    int64
#  24  MIN_RANK           464 non-null    int64
#  25  FG_PCT_RANK        464 non-null    int64
#  26  FG3M_RANK          464 non-null    int64
#  27  FG3_PCT_RANK       464 non-null    int64
#  28  FT_PCT_RANK        464 non-null    int64
#  29  OREB_RANK          464 non-null    int64
#  30  DREB_RANK          464 non-null    int64
#  31  REB_RANK           464 non-null    int64
#  32  AST_RANK           464 non-null    int64
#  33  TOV_RANK           464 non-null    int64
#  34  STL_RANK           464 non-null    int64
#  35  BLK_RANK           464 non-null    int64
#  36  BLKA_RANK          464 non-null    int64
#  37  PF_RANK            464 non-null    int64
#  38  PFD_RANK           464 non-null    int64
#  39  PTS_RANK           464 non-null    int64
#  40  PLUS_MINUS_RANK    464 non-null    int64
#  41  DD2_RANK           464 non-null    int64
#  42  TD3_RANK           464 non-null    int64
# dtypes: float64(14), int32(1), int64(26), object(2)
# memory usage: 157.7+ KB
# None
# Null values: 0
#
# ---------------------------
#
# Season: 2005-06
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 458 entries, 0 to 457
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PLAYER_ID          458 non-null    int64
#  1   PLAYER_NAME        458 non-null    object
#  2   TEAM_ID            458 non-null    int64
#  3   TEAM_ABBREVIATION  458 non-null    object
#  4   AGE                458 non-null    int32
#  5   FG_PCT             458 non-null    float64
#  6   FG3M               458 non-null    float64
#  7   FG3_PCT            458 non-null    float64
#  8   FT_PCT             458 non-null    float64
#  9   OREB               458 non-null    float64
#  10  REB                458 non-null    float64
#  11  AST                458 non-null    float64
#  12  TOV                458 non-null    float64
#  13  STL                458 non-null    float64
#  14  BLK                458 non-null    float64
#  15  BLKA               458 non-null    float64
#  16  PFD                458 non-null    float64
#  17  PTS                458 non-null    float64
#  18  PLUS_MINUS         458 non-null    float64
#  19  DD2                458 non-null    int64
#  20  TD3                458 non-null    int64
#  21  GP_RANK            458 non-null    int64
#  22  W_RANK             458 non-null    int64
#  23  W_PCT_RANK         458 non-null    int64
#  24  MIN_RANK           458 non-null    int64
#  25  FG_PCT_RANK        458 non-null    int64
#  26  FG3M_RANK          458 non-null    int64
#  27  FG3_PCT_RANK       458 non-null    int64
#  28  FT_PCT_RANK        458 non-null    int64
#  29  OREB_RANK          458 non-null    int64
#  30  DREB_RANK          458 non-null    int64
#  31  REB_RANK           458 non-null    int64
#  32  AST_RANK           458 non-null    int64
#  33  TOV_RANK           458 non-null    int64
#  34  STL_RANK           458 non-null    int64
#  35  BLK_RANK           458 non-null    int64
#  36  BLKA_RANK          458 non-null    int64
#  37  PF_RANK            458 non-null    int64
#  38  PFD_RANK           458 non-null    int64
#  39  PTS_RANK           458 non-null    int64
#  40  PLUS_MINUS_RANK    458 non-null    int64
#  41  DD2_RANK           458 non-null    int64
#  42  TD3_RANK           458 non-null    int64
# dtypes: float64(14), int32(1), int64(26), object(2)
# memory usage: 155.6+ KB
# None
# Null values: 0
#
# ---------------------------
#
# Season: 2006-07
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 458 entries, 0 to 457
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PLAYER_ID          458 non-null    int64
#  1   PLAYER_NAME        458 non-null    object
#  2   TEAM_ID            458 non-null    int64
#  3   TEAM_ABBREVIATION  458 non-null    object
#  4   AGE                458 non-null    int32
#  5   FG_PCT             458 non-null    float64
#  6   FG3M               458 non-null    float64
#  7   FG3_PCT            458 non-null    float64
#  8   FT_PCT             458 non-null    float64
#  9   OREB               458 non-null    float64
#  10  REB                458 non-null    float64
#  11  AST                458 non-null    float64
#  12  TOV                458 non-null    float64
#  13  STL                458 non-null    float64
#  14  BLK                458 non-null    float64
#  15  BLKA               458 non-null    float64
#  16  PFD                458 non-null    float64
#  17  PTS                458 non-null    float64
#  18  PLUS_MINUS         458 non-null    float64
#  19  DD2                458 non-null    int64
#  20  TD3                458 non-null    int64
#  21  GP_RANK            458 non-null    int64
#  22  W_RANK             458 non-null    int64
#  23  W_PCT_RANK         458 non-null    int64
#  24  MIN_RANK           458 non-null    int64
#  25  FG_PCT_RANK        458 non-null    int64
#  26  FG3M_RANK          458 non-null    int64
#  27  FG3_PCT_RANK       458 non-null    int64
#  28  FT_PCT_RANK        458 non-null    int64
#  29  OREB_RANK          458 non-null    int64
#  30  DREB_RANK          458 non-null    int64
#  31  REB_RANK           458 non-null    int64
#  32  AST_RANK           458 non-null    int64
#  33  TOV_RANK           458 non-null    int64
#  34  STL_RANK           458 non-null    int64
#  35  BLK_RANK           458 non-null    int64
#  36  BLKA_RANK          458 non-null    int64
#  37  PF_RANK            458 non-null    int64
#  38  PFD_RANK           458 non-null    int64
#  39  PTS_RANK           458 non-null    int64
#  40  PLUS_MINUS_RANK    458 non-null    int64
#  41  DD2_RANK           458 non-null    int64
#  42  TD3_RANK           458 non-null    int64
# dtypes: float64(14), int32(1), int64(26), object(2)
# memory usage: 155.6+ KB
# None
# Null values: 0
#
# ---------------------------
#
# Season: 2007-08
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 451 entries, 0 to 450
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PLAYER_ID          451 non-null    int64
#  1   PLAYER_NAME        451 non-null    object
#  2   TEAM_ID            451 non-null    int64
#  3   TEAM_ABBREVIATION  451 non-null    object
#  4   AGE                451 non-null    int32
#  5   FG_PCT             451 non-null    float64
#  6   FG3M               451 non-null    float64
#  7   FG3_PCT            451 non-null    float64
#  8   FT_PCT             451 non-null    float64
#  9   OREB               451 non-null    float64
#  10  REB                451 non-null    float64
#  11  AST                451 non-null    float64
#  12  TOV                451 non-null    float64
#  13  STL                451 non-null    float64
#  14  BLK                451 non-null    float64
#  15  BLKA               451 non-null    float64
#  16  PFD                451 non-null    float64
#  17  PTS                451 non-null    float64
#  18  PLUS_MINUS         451 non-null    float64
#  19  DD2                451 non-null    int64
#  20  TD3                451 non-null    int64
#  21  GP_RANK            451 non-null    int64
#  22  W_RANK             451 non-null    int64
#  23  W_PCT_RANK         451 non-null    int64
#  24  MIN_RANK           451 non-null    int64
#  25  FG_PCT_RANK        451 non-null    int64
#  26  FG3M_RANK          451 non-null    int64
#  27  FG3_PCT_RANK       451 non-null    int64
#  28  FT_PCT_RANK        451 non-null    int64
#  29  OREB_RANK          451 non-null    int64
#  30  DREB_RANK          451 non-null    int64
#  31  REB_RANK           451 non-null    int64
#  32  AST_RANK           451 non-null    int64
#  33  TOV_RANK           451 non-null    int64
#  34  STL_RANK           451 non-null    int64
#  35  BLK_RANK           451 non-null    int64
#  36  BLKA_RANK          451 non-null    int64
#  37  PF_RANK            451 non-null    int64
#  38  PFD_RANK           451 non-null    int64
#  39  PTS_RANK           451 non-null    int64
#  40  PLUS_MINUS_RANK    451 non-null    int64
#  41  DD2_RANK           451 non-null    int64
#  42  TD3_RANK           451 non-null    int64
# dtypes: float64(14), int32(1), int64(26), object(2)
# memory usage: 153.3+ KB
# None
# Null values: 0
#
# ---------------------------
#
# Season: 2008-09
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 445 entries, 0 to 444
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PLAYER_ID          445 non-null    int64
#  1   PLAYER_NAME        445 non-null    object
#  2   TEAM_ID            445 non-null    int64
#  3   TEAM_ABBREVIATION  445 non-null    object
#  4   AGE                445 non-null    int32
#  5   FG_PCT             445 non-null    float64
#  6   FG3M               445 non-null    float64
#  7   FG3_PCT            445 non-null    float64
#  8   FT_PCT             445 non-null    float64
#  9   OREB               445 non-null    float64
#  10  REB                445 non-null    float64
#  11  AST                445 non-null    float64
#  12  TOV                445 non-null    float64
#  13  STL                445 non-null    float64
#  14  BLK                445 non-null    float64
#  15  BLKA               445 non-null    float64
#  16  PFD                445 non-null    float64
#  17  PTS                445 non-null    float64
#  18  PLUS_MINUS         445 non-null    float64
#  19  DD2                445 non-null    int64
#  20  TD3                445 non-null    int64
#  21  GP_RANK            445 non-null    int64
#  22  W_RANK             445 non-null    int64
#  23  W_PCT_RANK         445 non-null    int64
#  24  MIN_RANK           445 non-null    int64
#  25  FG_PCT_RANK        445 non-null    int64
#  26  FG3M_RANK          445 non-null    int64
#  27  FG3_PCT_RANK       445 non-null    int64
#  28  FT_PCT_RANK        445 non-null    int64
#  29  OREB_RANK          445 non-null    int64
#  30  DREB_RANK          445 non-null    int64
#  31  REB_RANK           445 non-null    int64
#  32  AST_RANK           445 non-null    int64
#  33  TOV_RANK           445 non-null    int64
#  34  STL_RANK           445 non-null    int64
#  35  BLK_RANK           445 non-null    int64
#  36  BLKA_RANK          445 non-null    int64
#  37  PF_RANK            445 non-null    int64
#  38  PFD_RANK           445 non-null    int64
#  39  PTS_RANK           445 non-null    int64
#  40  PLUS_MINUS_RANK    445 non-null    int64
#  41  DD2_RANK           445 non-null    int64
#  42  TD3_RANK           445 non-null    int64
# dtypes: float64(14), int32(1), int64(26), object(2)
# memory usage: 151.2+ KB
# None
# Null values: 0
#
# ---------------------------
#
# Season: 2009-10
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 442 entries, 0 to 441
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PLAYER_ID          442 non-null    int64
#  1   PLAYER_NAME        442 non-null    object
#  2   TEAM_ID            442 non-null    int64
#  3   TEAM_ABBREVIATION  442 non-null    object
#  4   AGE                442 non-null    int32
#  5   FG_PCT             442 non-null    float64
#  6   FG3M               442 non-null    float64
#  7   FG3_PCT            442 non-null    float64
#  8   FT_PCT             442 non-null    float64
#  9   OREB               442 non-null    float64
#  10  REB                442 non-null    float64
#  11  AST                442 non-null    float64
#  12  TOV                442 non-null    float64
#  13  STL                442 non-null    float64
#  14  BLK                442 non-null    float64
#  15  BLKA               442 non-null    float64
#  16  PFD                442 non-null    float64
#  17  PTS                442 non-null    float64
#  18  PLUS_MINUS         442 non-null    float64
#  19  DD2                442 non-null    int64
#  20  TD3                442 non-null    int64
#  21  GP_RANK            442 non-null    int64
#  22  W_RANK             442 non-null    int64
#  23  W_PCT_RANK         442 non-null    int64
#  24  MIN_RANK           442 non-null    int64
#  25  FG_PCT_RANK        442 non-null    int64
#  26  FG3M_RANK          442 non-null    int64
#  27  FG3_PCT_RANK       442 non-null    int64
#  28  FT_PCT_RANK        442 non-null    int64
#  29  OREB_RANK          442 non-null    int64
#  30  DREB_RANK          442 non-null    int64
#  31  REB_RANK           442 non-null    int64
#  32  AST_RANK           442 non-null    int64
#  33  TOV_RANK           442 non-null    int64
#  34  STL_RANK           442 non-null    int64
#  35  BLK_RANK           442 non-null    int64
#  36  BLKA_RANK          442 non-null    int64
#  37  PF_RANK            442 non-null    int64
#  38  PFD_RANK           442 non-null    int64
#  39  PTS_RANK           442 non-null    int64
#  40  PLUS_MINUS_RANK    442 non-null    int64
#  41  DD2_RANK           442 non-null    int64
#  42  TD3_RANK           442 non-null    int64
# dtypes: float64(14), int32(1), int64(26), object(2)
# memory usage: 150.2+ KB
# None
# Null values: 0
#
# ---------------------------
#
# Season: 2010-11
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 452 entries, 0 to 451
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PLAYER_ID          452 non-null    int64
#  1   PLAYER_NAME        452 non-null    object
#  2   TEAM_ID            452 non-null    int64
#  3   TEAM_ABBREVIATION  452 non-null    object
#  4   AGE                452 non-null    int32
#  5   FG_PCT             452 non-null    float64
#  6   FG3M               452 non-null    float64
#  7   FG3_PCT            452 non-null    float64
#  8   FT_PCT             452 non-null    float64
#  9   OREB               452 non-null    float64
#  10  REB                452 non-null    float64
#  11  AST                452 non-null    float64
#  12  TOV                452 non-null    float64
#  13  STL                452 non-null    float64
#  14  BLK                452 non-null    float64
#  15  BLKA               452 non-null    float64
#  16  PFD                452 non-null    float64
#  17  PTS                452 non-null    float64
#  18  PLUS_MINUS         452 non-null    float64
#  19  DD2                452 non-null    int64
#  20  TD3                452 non-null    int64
#  21  GP_RANK            452 non-null    int64
#  22  W_RANK             452 non-null    int64
#  23  W_PCT_RANK         452 non-null    int64
#  24  MIN_RANK           452 non-null    int64
#  25  FG_PCT_RANK        452 non-null    int64
#  26  FG3M_RANK          452 non-null    int64
#  27  FG3_PCT_RANK       452 non-null    int64
#  28  FT_PCT_RANK        452 non-null    int64
#  29  OREB_RANK          452 non-null    int64
#  30  DREB_RANK          452 non-null    int64
#  31  REB_RANK           452 non-null    int64
#  32  AST_RANK           452 non-null    int64
#  33  TOV_RANK           452 non-null    int64
#  34  STL_RANK           452 non-null    int64
#  35  BLK_RANK           452 non-null    int64
#  36  BLKA_RANK          452 non-null    int64
#  37  PF_RANK            452 non-null    int64
#  38  PFD_RANK           452 non-null    int64
#  39  PTS_RANK           452 non-null    int64
#  40  PLUS_MINUS_RANK    452 non-null    int64
#  41  DD2_RANK           452 non-null    int64
#  42  TD3_RANK           452 non-null    int64
# dtypes: float64(14), int32(1), int64(26), object(2)
# memory usage: 153.6+ KB
# None
# Null values: 0
#
# ---------------------------
#
# Season: 2011-12
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 478 entries, 0 to 477
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PLAYER_ID          478 non-null    int64
#  1   PLAYER_NAME        478 non-null    object
#  2   TEAM_ID            478 non-null    int64
#  3   TEAM_ABBREVIATION  478 non-null    object
#  4   AGE                478 non-null    int32
#  5   FG_PCT             478 non-null    float64
#  6   FG3M               478 non-null    float64
#  7   FG3_PCT            478 non-null    float64
#  8   FT_PCT             478 non-null    float64
#  9   OREB               478 non-null    float64
#  10  REB                478 non-null    float64
#  11  AST                478 non-null    float64
#  12  TOV                478 non-null    float64
#  13  STL                478 non-null    float64
#  14  BLK                478 non-null    float64
#  15  BLKA               478 non-null    float64
#  16  PFD                478 non-null    float64
#  17  PTS                478 non-null    float64
#  18  PLUS_MINUS         478 non-null    float64
#  19  DD2                478 non-null    int64
#  20  TD3                478 non-null    int64
#  21  GP_RANK            478 non-null    int64
#  22  W_RANK             478 non-null    int64
#  23  W_PCT_RANK         478 non-null    int64
#  24  MIN_RANK           478 non-null    int64
#  25  FG_PCT_RANK        478 non-null    int64
#  26  FG3M_RANK          478 non-null    int64
#  27  FG3_PCT_RANK       478 non-null    int64
#  28  FT_PCT_RANK        478 non-null    int64
#  29  OREB_RANK          478 non-null    int64
#  30  DREB_RANK          478 non-null    int64
#  31  REB_RANK           478 non-null    int64
#  32  AST_RANK           478 non-null    int64
#  33  TOV_RANK           478 non-null    int64
#  34  STL_RANK           478 non-null    int64
#  35  BLK_RANK           478 non-null    int64
#  36  BLKA_RANK          478 non-null    int64
#  37  PF_RANK            478 non-null    int64
#  38  PFD_RANK           478 non-null    int64
#  39  PTS_RANK           478 non-null    int64
#  40  PLUS_MINUS_RANK    478 non-null    int64
#  41  DD2_RANK           478 non-null    int64
#  42  TD3_RANK           478 non-null    int64
# dtypes: float64(14), int32(1), int64(26), object(2)
# memory usage: 162.4+ KB
# None
# Null values: 0
#
# ---------------------------
#
# Season: 2012-13
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 469 entries, 0 to 468
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PLAYER_ID          469 non-null    int64
#  1   PLAYER_NAME        469 non-null    object
#  2   TEAM_ID            469 non-null    int64
#  3   TEAM_ABBREVIATION  469 non-null    object
#  4   AGE                469 non-null    int32
#  5   FG_PCT             469 non-null    float64
#  6   FG3M               469 non-null    float64
#  7   FG3_PCT            469 non-null    float64
#  8   FT_PCT             469 non-null    float64
#  9   OREB               469 non-null    float64
#  10  REB                469 non-null    float64
#  11  AST                469 non-null    float64
#  12  TOV                469 non-null    float64
#  13  STL                469 non-null    float64
#  14  BLK                469 non-null    float64
#  15  BLKA               469 non-null    float64
#  16  PFD                469 non-null    float64
#  17  PTS                469 non-null    float64
#  18  PLUS_MINUS         469 non-null    float64
#  19  DD2                469 non-null    int64
#  20  TD3                469 non-null    int64
#  21  GP_RANK            469 non-null    int64
#  22  W_RANK             469 non-null    int64
#  23  W_PCT_RANK         469 non-null    int64
#  24  MIN_RANK           469 non-null    int64
#  25  FG_PCT_RANK        469 non-null    int64
#  26  FG3M_RANK          469 non-null    int64
#  27  FG3_PCT_RANK       469 non-null    int64
#  28  FT_PCT_RANK        469 non-null    int64
#  29  OREB_RANK          469 non-null    int64
#  30  DREB_RANK          469 non-null    int64
#  31  REB_RANK           469 non-null    int64
#  32  AST_RANK           469 non-null    int64
#  33  TOV_RANK           469 non-null    int64
#  34  STL_RANK           469 non-null    int64
#  35  BLK_RANK           469 non-null    int64
#  36  BLKA_RANK          469 non-null    int64
#  37  PF_RANK            469 non-null    int64
#  38  PFD_RANK           469 non-null    int64
#  39  PTS_RANK           469 non-null    int64
#  40  PLUS_MINUS_RANK    469 non-null    int64
#  41  DD2_RANK           469 non-null    int64
#  42  TD3_RANK           469 non-null    int64
# dtypes: float64(14), int32(1), int64(26), object(2)
# memory usage: 159.4+ KB
# None
# Null values: 0
#
# ---------------------------
#
# Season: 2013-14
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 482 entries, 0 to 481
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PLAYER_ID          482 non-null    int64
#  1   PLAYER_NAME        482 non-null    object
#  2   TEAM_ID            482 non-null    int64
#  3   TEAM_ABBREVIATION  482 non-null    object
#  4   AGE                482 non-null    int32
#  5   FG_PCT             482 non-null    float64
#  6   FG3M               482 non-null    float64
#  7   FG3_PCT            482 non-null    float64
#  8   FT_PCT             482 non-null    float64
#  9   OREB               482 non-null    float64
#  10  REB                482 non-null    float64
#  11  AST                482 non-null    float64
#  12  TOV                482 non-null    float64
#  13  STL                482 non-null    float64
#  14  BLK                482 non-null    float64
#  15  BLKA               482 non-null    float64
#  16  PFD                482 non-null    float64
#  17  PTS                482 non-null    float64
#  18  PLUS_MINUS         482 non-null    float64
#  19  DD2                482 non-null    int64
#  20  TD3                482 non-null    int64
#  21  GP_RANK            482 non-null    int64
#  22  W_RANK             482 non-null    int64
#  23  W_PCT_RANK         482 non-null    int64
#  24  MIN_RANK           482 non-null    int64
#  25  FG_PCT_RANK        482 non-null    int64
#  26  FG3M_RANK          482 non-null    int64
#  27  FG3_PCT_RANK       482 non-null    int64
#  28  FT_PCT_RANK        482 non-null    int64
#  29  OREB_RANK          482 non-null    int64
#  30  DREB_RANK          482 non-null    int64
#  31  REB_RANK           482 non-null    int64
#  32  AST_RANK           482 non-null    int64
#  33  TOV_RANK           482 non-null    int64
#  34  STL_RANK           482 non-null    int64
#  35  BLK_RANK           482 non-null    int64
#  36  BLKA_RANK          482 non-null    int64
#  37  PF_RANK            482 non-null    int64
#  38  PFD_RANK           482 non-null    int64
#  39  PTS_RANK           482 non-null    int64
#  40  PLUS_MINUS_RANK    482 non-null    int64
#  41  DD2_RANK           482 non-null    int64
#  42  TD3_RANK           482 non-null    int64
# dtypes: float64(14), int32(1), int64(26), object(2)
# memory usage: 163.8+ KB
# None
# Null values: 0
#
# ---------------------------
#
# Season: 2014-15
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 492 entries, 0 to 491
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PLAYER_ID          492 non-null    int64
#  1   PLAYER_NAME        492 non-null    object
#  2   TEAM_ID            492 non-null    int64
#  3   TEAM_ABBREVIATION  492 non-null    object
#  4   AGE                492 non-null    int32
#  5   FG_PCT             492 non-null    float64
#  6   FG3M               492 non-null    float64
#  7   FG3_PCT            492 non-null    float64
#  8   FT_PCT             492 non-null    float64
#  9   OREB               492 non-null    float64
#  10  REB                492 non-null    float64
#  11  AST                492 non-null    float64
#  12  TOV                492 non-null    float64
#  13  STL                492 non-null    float64
#  14  BLK                492 non-null    float64
#  15  BLKA               492 non-null    float64
#  16  PFD                492 non-null    float64
#  17  PTS                492 non-null    float64
#  18  PLUS_MINUS         492 non-null    float64
#  19  DD2                492 non-null    int64
#  20  TD3                492 non-null    int64
#  21  GP_RANK            492 non-null    int64
#  22  W_RANK             492 non-null    int64
#  23  W_PCT_RANK         492 non-null    int64
#  24  MIN_RANK           492 non-null    int64
#  25  FG_PCT_RANK        492 non-null    int64
#  26  FG3M_RANK          492 non-null    int64
#  27  FG3_PCT_RANK       492 non-null    int64
#  28  FT_PCT_RANK        492 non-null    int64
#  29  OREB_RANK          492 non-null    int64
#  30  DREB_RANK          492 non-null    int64
#  31  REB_RANK           492 non-null    int64
#  32  AST_RANK           492 non-null    int64
#  33  TOV_RANK           492 non-null    int64
#  34  STL_RANK           492 non-null    int64
#  35  BLK_RANK           492 non-null    int64
#  36  BLKA_RANK          492 non-null    int64
#  37  PF_RANK            492 non-null    int64
#  38  PFD_RANK           492 non-null    int64
#  39  PTS_RANK           492 non-null    int64
#  40  PLUS_MINUS_RANK    492 non-null    int64
#  41  DD2_RANK           492 non-null    int64
#  42  TD3_RANK           492 non-null    int64
# dtypes: float64(14), int32(1), int64(26), object(2)
# memory usage: 167.2+ KB
# None
# Null values: 0
#
# ---------------------------
#
# Season: 2015-16
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 476 entries, 0 to 475
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PLAYER_ID          476 non-null    int64
#  1   PLAYER_NAME        476 non-null    object
#  2   TEAM_ID            476 non-null    int64
#  3   TEAM_ABBREVIATION  476 non-null    object
#  4   AGE                476 non-null    int32
#  5   FG_PCT             476 non-null    float64
#  6   FG3M               476 non-null    float64
#  7   FG3_PCT            476 non-null    float64
#  8   FT_PCT             476 non-null    float64
#  9   OREB               476 non-null    float64
#  10  REB                476 non-null    float64
#  11  AST                476 non-null    float64
#  12  TOV                476 non-null    float64
#  13  STL                476 non-null    float64
#  14  BLK                476 non-null    float64
#  15  BLKA               476 non-null    float64
#  16  PFD                476 non-null    float64
#  17  PTS                476 non-null    float64
#  18  PLUS_MINUS         476 non-null    float64
#  19  DD2                476 non-null    int64
#  20  TD3                476 non-null    int64
#  21  GP_RANK            476 non-null    int64
#  22  W_RANK             476 non-null    int64
#  23  W_PCT_RANK         476 non-null    int64
#  24  MIN_RANK           476 non-null    int64
#  25  FG_PCT_RANK        476 non-null    int64
#  26  FG3M_RANK          476 non-null    int64
#  27  FG3_PCT_RANK       476 non-null    int64
#  28  FT_PCT_RANK        476 non-null    int64
#  29  OREB_RANK          476 non-null    int64
#  30  DREB_RANK          476 non-null    int64
#  31  REB_RANK           476 non-null    int64
#  32  AST_RANK           476 non-null    int64
#  33  TOV_RANK           476 non-null    int64
#  34  STL_RANK           476 non-null    int64
#  35  BLK_RANK           476 non-null    int64
#  36  BLKA_RANK          476 non-null    int64
#  37  PF_RANK            476 non-null    int64
#  38  PFD_RANK           476 non-null    int64
#  39  PTS_RANK           476 non-null    int64
#  40  PLUS_MINUS_RANK    476 non-null    int64
#  41  DD2_RANK           476 non-null    int64
#  42  TD3_RANK           476 non-null    int64
# dtypes: float64(14), int32(1), int64(26), object(2)
# memory usage: 161.8+ KB
# None
# Null values: 0
#
# ---------------------------
#
# Season: 2016-17
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 486 entries, 0 to 485
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PLAYER_ID          486 non-null    int64
#  1   PLAYER_NAME        486 non-null    object
#  2   TEAM_ID            486 non-null    int64
#  3   TEAM_ABBREVIATION  486 non-null    object
#  4   AGE                486 non-null    int32
#  5   FG_PCT             486 non-null    float64
#  6   FG3M               486 non-null    float64
#  7   FG3_PCT            486 non-null    float64
#  8   FT_PCT             486 non-null    float64
#  9   OREB               486 non-null    float64
#  10  REB                486 non-null    float64
#  11  AST                486 non-null    float64
#  12  TOV                486 non-null    float64
#  13  STL                486 non-null    float64
#  14  BLK                486 non-null    float64
#  15  BLKA               486 non-null    float64
#  16  PFD                486 non-null    float64
#  17  PTS                486 non-null    float64
#  18  PLUS_MINUS         486 non-null    float64
#  19  DD2                486 non-null    int64
#  20  TD3                486 non-null    int64
#  21  GP_RANK            486 non-null    int64
#  22  W_RANK             486 non-null    int64
#  23  W_PCT_RANK         486 non-null    int64
#  24  MIN_RANK           486 non-null    int64
#  25  FG_PCT_RANK        486 non-null    int64
#  26  FG3M_RANK          486 non-null    int64
#  27  FG3_PCT_RANK       486 non-null    int64
#  28  FT_PCT_RANK        486 non-null    int64
#  29  OREB_RANK          486 non-null    int64
#  30  DREB_RANK          486 non-null    int64
#  31  REB_RANK           486 non-null    int64
#  32  AST_RANK           486 non-null    int64
#  33  TOV_RANK           486 non-null    int64
#  34  STL_RANK           486 non-null    int64
#  35  BLK_RANK           486 non-null    int64
#  36  BLKA_RANK          486 non-null    int64
#  37  PF_RANK            486 non-null    int64
#  38  PFD_RANK           486 non-null    int64
#  39  PTS_RANK           486 non-null    int64
#  40  PLUS_MINUS_RANK    486 non-null    int64
#  41  DD2_RANK           486 non-null    int64
#  42  TD3_RANK           486 non-null    int64
# dtypes: float64(14), int32(1), int64(26), object(2)
# memory usage: 165.2+ KB
# None
# Null values: 0
#
# ---------------------------
#
# Season: 2017-18
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 540 entries, 0 to 539
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PLAYER_ID          540 non-null    int64
#  1   PLAYER_NAME        540 non-null    object
#  2   TEAM_ID            540 non-null    int64
#  3   TEAM_ABBREVIATION  540 non-null    object
#  4   AGE                540 non-null    int32
#  5   FG_PCT             540 non-null    float64
#  6   FG3M               540 non-null    float64
#  7   FG3_PCT            540 non-null    float64
#  8   FT_PCT             540 non-null    float64
#  9   OREB               540 non-null    float64
#  10  REB                540 non-null    float64
#  11  AST                540 non-null    float64
#  12  TOV                540 non-null    float64
#  13  STL                540 non-null    float64
#  14  BLK                540 non-null    float64
#  15  BLKA               540 non-null    float64
#  16  PFD                540 non-null    float64
#  17  PTS                540 non-null    float64
#  18  PLUS_MINUS         540 non-null    float64
#  19  DD2                540 non-null    int64
#  20  TD3                540 non-null    int64
#  21  GP_RANK            540 non-null    int64
#  22  W_RANK             540 non-null    int64
#  23  W_PCT_RANK         540 non-null    int64
#  24  MIN_RANK           540 non-null    int64
#  25  FG_PCT_RANK        540 non-null    int64
#  26  FG3M_RANK          540 non-null    int64
#  27  FG3_PCT_RANK       540 non-null    int64
#  28  FT_PCT_RANK        540 non-null    int64
#  29  OREB_RANK          540 non-null    int64
#  30  DREB_RANK          540 non-null    int64
#  31  REB_RANK           540 non-null    int64
#  32  AST_RANK           540 non-null    int64
#  33  TOV_RANK           540 non-null    int64
#  34  STL_RANK           540 non-null    int64
#  35  BLK_RANK           540 non-null    int64
#  36  BLKA_RANK          540 non-null    int64
#  37  PF_RANK            540 non-null    int64
#  38  PFD_RANK           540 non-null    int64
#  39  PTS_RANK           540 non-null    int64
#  40  PLUS_MINUS_RANK    540 non-null    int64
#  41  DD2_RANK           540 non-null    int64
#  42  TD3_RANK           540 non-null    int64
# dtypes: float64(14), int32(1), int64(26), object(2)
# memory usage: 183.5+ KB
# None
# Null values: 0
#
# ---------------------------
#
# Season: 2018-19
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 530 entries, 0 to 529
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PLAYER_ID          530 non-null    int64
#  1   PLAYER_NAME        530 non-null    object
#  2   TEAM_ID            530 non-null    int64
#  3   TEAM_ABBREVIATION  530 non-null    object
#  4   AGE                530 non-null    int32
#  5   FG_PCT             530 non-null    float64
#  6   FG3M               530 non-null    float64
#  7   FG3_PCT            530 non-null    float64
#  8   FT_PCT             530 non-null    float64
#  9   OREB               530 non-null    float64
#  10  REB                530 non-null    float64
#  11  AST                530 non-null    float64
#  12  TOV                530 non-null    float64
#  13  STL                530 non-null    float64
#  14  BLK                530 non-null    float64
#  15  BLKA               530 non-null    float64
#  16  PFD                530 non-null    float64
#  17  PTS                530 non-null    float64
#  18  PLUS_MINUS         530 non-null    float64
#  19  DD2                530 non-null    int64
#  20  TD3                530 non-null    int64
#  21  GP_RANK            530 non-null    int64
#  22  W_RANK             530 non-null    int64
#  23  W_PCT_RANK         530 non-null    int64
#  24  MIN_RANK           530 non-null    int64
#  25  FG_PCT_RANK        530 non-null    int64
#  26  FG3M_RANK          530 non-null    int64
#  27  FG3_PCT_RANK       530 non-null    int64
#  28  FT_PCT_RANK        530 non-null    int64
#  29  OREB_RANK          530 non-null    int64
#  30  DREB_RANK          530 non-null    int64
#  31  REB_RANK           530 non-null    int64
#  32  AST_RANK           530 non-null    int64
#  33  TOV_RANK           530 non-null    int64
#  34  STL_RANK           530 non-null    int64
#  35  BLK_RANK           530 non-null    int64
#  36  BLKA_RANK          530 non-null    int64
#  37  PF_RANK            530 non-null    int64
#  38  PFD_RANK           530 non-null    int64
#  39  PTS_RANK           530 non-null    int64
#  40  PLUS_MINUS_RANK    530 non-null    int64
#  41  DD2_RANK           530 non-null    int64
#  42  TD3_RANK           530 non-null    int64
# dtypes: float64(14), int32(1), int64(26), object(2)
# memory usage: 180.1+ KB
# None
# Null values: 0
#
# ---------------------------
#
# Season: 2019-20
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 529 entries, 0 to 528
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PLAYER_ID          529 non-null    int64
#  1   PLAYER_NAME        529 non-null    object
#  2   TEAM_ID            529 non-null    int64
#  3   TEAM_ABBREVIATION  529 non-null    object
#  4   AGE                529 non-null    int32
#  5   FG_PCT             529 non-null    float64
#  6   FG3M               529 non-null    float64
#  7   FG3_PCT            529 non-null    float64
#  8   FT_PCT             529 non-null    float64
#  9   OREB               529 non-null    float64
#  10  REB                529 non-null    float64
#  11  AST                529 non-null    float64
#  12  TOV                529 non-null    float64
#  13  STL                529 non-null    float64
#  14  BLK                529 non-null    float64
#  15  BLKA               529 non-null    float64
#  16  PFD                529 non-null    float64
#  17  PTS                529 non-null    float64
#  18  PLUS_MINUS         529 non-null    float64
#  19  DD2                529 non-null    int64
#  20  TD3                529 non-null    int64
#  21  GP_RANK            529 non-null    int64
#  22  W_RANK             529 non-null    int64
#  23  W_PCT_RANK         529 non-null    int64
#  24  MIN_RANK           529 non-null    int64
#  25  FG_PCT_RANK        529 non-null    int64
#  26  FG3M_RANK          529 non-null    int64
#  27  FG3_PCT_RANK       529 non-null    int64
#  28  FT_PCT_RANK        529 non-null    int64
#  29  OREB_RANK          529 non-null    int64
#  30  DREB_RANK          529 non-null    int64
#  31  REB_RANK           529 non-null    int64
#  32  AST_RANK           529 non-null    int64
#  33  TOV_RANK           529 non-null    int64
#  34  STL_RANK           529 non-null    int64
#  35  BLK_RANK           529 non-null    int64
#  36  BLKA_RANK          529 non-null    int64
#  37  PF_RANK            529 non-null    int64
#  38  PFD_RANK           529 non-null    int64
#  39  PTS_RANK           529 non-null    int64
#  40  PLUS_MINUS_RANK    529 non-null    int64
#  41  DD2_RANK           529 non-null    int64
#  42  TD3_RANK           529 non-null    int64
# dtypes: float64(14), int32(1), int64(26), object(2)
# memory usage: 179.8+ KB
# None
# Null values: 0
#
# ---------------------------
#
# Season: 2020-21
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 540 entries, 0 to 539
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PLAYER_ID          540 non-null    int64
#  1   PLAYER_NAME        540 non-null    object
#  2   TEAM_ID            540 non-null    int64
#  3   TEAM_ABBREVIATION  540 non-null    object
#  4   AGE                540 non-null    int32
#  5   FG_PCT             540 non-null    float64
#  6   FG3M               540 non-null    float64
#  7   FG3_PCT            540 non-null    float64
#  8   FT_PCT             540 non-null    float64
#  9   OREB               540 non-null    float64
#  10  REB                540 non-null    float64
#  11  AST                540 non-null    float64
#  12  TOV                540 non-null    float64
#  13  STL                540 non-null    float64
#  14  BLK                540 non-null    float64
#  15  BLKA               540 non-null    float64
#  16  PFD                540 non-null    float64
#  17  PTS                540 non-null    float64
#  18  PLUS_MINUS         540 non-null    float64
#  19  DD2                540 non-null    int64
#  20  TD3                540 non-null    int64
#  21  GP_RANK            540 non-null    int64
#  22  W_RANK             540 non-null    int64
#  23  W_PCT_RANK         540 non-null    int64
#  24  MIN_RANK           540 non-null    int64
#  25  FG_PCT_RANK        540 non-null    int64
#  26  FG3M_RANK          540 non-null    int64
#  27  FG3_PCT_RANK       540 non-null    int64
#  28  FT_PCT_RANK        540 non-null    int64
#  29  OREB_RANK          540 non-null    int64
#  30  DREB_RANK          540 non-null    int64
#  31  REB_RANK           540 non-null    int64
#  32  AST_RANK           540 non-null    int64
#  33  TOV_RANK           540 non-null    int64
#  34  STL_RANK           540 non-null    int64
#  35  BLK_RANK           540 non-null    int64
#  36  BLKA_RANK          540 non-null    int64
#  37  PF_RANK            540 non-null    int64
#  38  PFD_RANK           540 non-null    int64
#  39  PTS_RANK           540 non-null    int64
#  40  PLUS_MINUS_RANK    540 non-null    int64
#  41  DD2_RANK           540 non-null    int64
#  42  TD3_RANK           540 non-null    int64
# dtypes: float64(14), int32(1), int64(26), object(2)
# memory usage: 183.5+ KB
# None
# Null values: 0
#
# ---------------------------
