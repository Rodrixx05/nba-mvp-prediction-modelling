# %%
import pandas as pd
import numpy as np
import os

from sklearn import metrics
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor

from sklearn_pandas import DataFrameMapper

import xgboost as xgb

from imblearn.over_sampling import RandomOverSampler, SMOTENC

import mlflow

# %%
dataframes_path = os.path.join(os.getcwd(), 'dataframes')

# %%
df = pd.read_pickle(os.path.join(dataframes_path, 'complete_stats.pkl'))

# %%
def check_rk_season(df, rk_season_pairs):
    return df.apply(lambda x: (x['Rk'], x['Season']) in rk_season_pairs, axis = 1)

# %% [markdown]
# - Drop players with more than one team
# - Index with tuple for Rk & Player
# - Drop columns, Rk GT, Votes, MaxVotes
# - LabelEncode for Player, Pos and Team
# - Separate types of columns

# %%
class DropPlayersMultiTeams(BaseEstimator, TransformerMixin):

    def __init__(self):
        pass
        
    def fit(self, X, y = None):
        return self
    
    def transform(self, X, y = None):   
        df_tot = X[X['Tm'] == 'TOT']
        rk_season_pairs = list(zip(df_tot['Rk'], df_tot['Season']))
        df_tot_full = X[check_rk_season(X, rk_season_pairs)]
        drop_index = df_tot_full[df_tot_full['Tm'] != 'TOT'].index
        return X.drop(drop_index).reset_index(drop = True)

# %%
class DropColumns(BaseEstimator, TransformerMixin):
    def __init__(self, cols_to_drop):
        self.cols_to_drop = cols_to_drop
    
    def fit(self, X, y = None):
        return self
    
    def transform(self, X, y = None):
        return X.drop(columns = self.cols_to_drop)

# %%
class SetIndex(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass
    
    def fit(self, X, y = None):
        return self
    
    def transform(self, X, y = None):
        return X.set_index(['Rk', 'Season'], drop = False)

# %%
class OutlierFilter(BaseEstimator, TransformerMixin):
    '''
    Clase que filtra los outliers utilizando np.quantile()
    Los cuantiles a filtrar así como las columnas a filtrar son los parámetros de la clase.
    '''
    
    def __init__(self, q, col_to_filter):
        self.q = q
        self.col_to_filter = col_to_filter
        
    def fit(self, X, y = None):
        return self
    
    def transform(self, X, y = None):
        '''
        El método considera outlier a aquel cliente que es outlier en todas las columnas que le pasas.
        Es decir: si tiene que filtrar importe y número de pedidos, sólo va a eliminar aquellos clientes
        que son outlier tanto en importe como número de pedidos. Si eres outlier en importe pero no en pedido
        no se te va a filtrar del dataset.
        '''
        
        # lista vacía
        criteria_list = []
        
        # agregamos a la lista los clientes que no son outliers
        for col in self.col_to_filter:
            criteria = (X[col] > np.quantile(X[col], q = self.q)) & (X[col] < np.quantile(X[col], q = 1 - self.q))
            criteria_list.append(criteria)
            
        # si hay más de 1 columna
        if len(self.col_to_filter) > 1:
            
            # creamos el criterio global: es decir outlier en todas las columnas
            global_criteria = criteria_list[0]
            
            for criteria in criteria_list[1:]:
                global_criteria = global_criteria & criteria
                
        else:
            global_criteria = criteria_list[0]
            
        # filtramos nuestra dataframe
        X = X[global_criteria]
        
        # guardamos el índice como parámetro de la clase porque en caso contrario lo perderíamos.
        self.index = X.index
        
        return X

# %%
class DropPlayers(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.players_list = []
    
    def fit(self, X, y = None):
        self.players_list_ = X[['Player']]
        return self
    
    def transform(self, X, y = None):
        return X.drop('Player', axis = 1)

# %%
cols_to_drop = ['Rk', 'GT', 'Votes', 'MaxVotes', 'FG_tot', '3PA_tot', '2PA_tot', 'FGA_tot_rank', 'Tm', 'Pos']
cols_to_filter = ['PER', 'WS/48', 'BPM', 'USG%']
cols_to_ohe = ['Pos', 'Tm']

# %%
pipe = Pipeline(steps = [
    ('DropPlayersMultiTeams', DropPlayersMultiTeams()),
    ('OutlierFilter', OutlierFilter(q = .0005, col_to_filter = cols_to_filter)),
    ('SetIndex', SetIndex()),
    ('DropColumns', DropColumns(cols_to_drop)),
    ('DropPlayers', DropPlayers()),
    # ('OneHotEncoder', DataFrameMapper([(cols_to_ohe, OneHotEncoder(drop = 'if_binary'), {'alias': 'Pos_Tm'})], input_df=True, df_out=True, default = None))
])

# %%
df = pipe.fit_transform(df)

# %%
df.head()
# Out:
#            Age   G  GS  MP_pg  FG_pg  FGA_pg    FG%  3P_pg  3PA_pg    3P%  \
# Rk Season
# 1  1980     32  82 -10   38.3   10.2    16.9  0.604    0.0     0.0  0.000
# 2  1980     25  67 -10   18.2    2.3     4.7  0.481    0.0     0.0  0.000
# 3  1980     25  75 -10   28.9    6.2    11.7  0.531    0.0     0.0  0.000
# 4  1980     31  80  80   35.8    4.8     9.9  0.482    0.1     0.2  0.222
# 5  1980     31  26 -10   21.5    1.0     2.3  0.450    0.0     0.0  0.000
#
#            ...  DWS_rank  WS_rank  WS/48_rank  OBPM_rank  DBPM_rank  BPM_rank  \
# Rk Season  ...
# 1  1980    ...         3        1           1          5          7         2
# 2  1980    ...        44       71          83         50         32        54
# 3  1980    ...        13       27          21         23         11        12
# 4  1980    ...        23       14          25         26         33        31
# 5  1980    ...        47       85         109         63         21        56
#
#            VORP_rank  %W_rank  %GS  Share
# Rk Season
# 1  1980            1        2 -1.0  0.665
# 2  1980           41       44 -1.0  0.000
# 3  1980           12        6 -1.0  0.000
# 4  1980           20        1  1.0  0.009
# 5  1980           42       38 -1.0  0.000
#
# [5 rows x 127 columns]

# %%
len(df[df['Season'] > 2015]) / len(df)
# Out:
# 0.17507805847289243

# %%
val_df = df[df['Season'] > 2015]
dev_df = df[df['Season'] <= 2015]

# %%
def oversample(df, os_param = 'ros', sampling_strategy = .3):
    df_os = df.copy()
    df_os.loc[:, 'Contender'] = (df_os['Share'] > 0) * 1
    df_X = df_os.drop('Contender', axis = 1)
    df_y = df_os[['Contender']]

    if os_param == 'smote':
        int_cols = df_X.select_dtypes('int').columns
        cat_index = [df_X.columns.get_loc(column) for column in int_cols]
        os_technique = SMOTENC(sampling_strategy = sampling_strategy, random_state=23, categorical_features= cat_index)  
    else:
        os_technique = RandomOverSampler(sampling_strategy = sampling_strategy, random_state = 23)

    X_resampled, y_resampled = os_technique.fit_resample(df_X, df_y)
    df_ros = pd.concat([X_resampled, y_resampled], axis = 1)
    df_ros.drop('Contender', axis = 1, inplace = True)

    return df_ros, sampling_strategy

# %%
dev_df, sampling_ratio = oversample(dev_df, os_param = 'smote', sampling_strategy = .25)

# %%
dev_df_X = dev_df.drop('Share', axis=1)
dev_df_y = dev_df[['Share']]

val_df_X = val_df.drop('Share', axis=1)
val_df_y = val_df[['Share']]

# %%
X_train, X_test, y_train, y_test = train_test_split(
                                        dev_df_X,
                                        dev_df_y,
                                        test_size = 0.2,
                                        random_state = 23
                                     )

# %%
datasets = {'train': X_train, 'test': X_test, 'val': val_df_X}
real_targets = {'train': y_train, 'test': y_test, 'val': val_df_y}

# %%
mlflow.set_experiment('NBA MVP prediction model')
# Out:
# <Experiment: artifact_location='file:///C:/Users/marcr/OneDrive/Documents/Data%20Science/NBA%20Project/mlruns/0', experiment_id='0', lifecycle_stage='active', name='NBA MVP prediction model', tags={}>

# %%
def eval_metrics(actual, predicted):
    rmse = np.sqrt(metrics.mean_squared_error(actual, predicted))
    mae = metrics.mean_absolute_error(actual, predicted)
    r2 = metrics.r2_score(actual, predicted)

    return {'rmse': rmse, 'mae': mae, 'r2': r2}

# %%
def retrieve_best(grid_object):
    best_model = grid_object.best_estimator_    
    best_params = grid_object.best_params_
    best_cv_score = grid_object.best_score_
    best_params['best_ntree_limit'] = best_model.best_ntree_limit
    return best_model, best_params, best_cv_score

# %%
def predict_model(model, datasets):
    results_dict = {}
    for type, dataset in datasets.items():
        prediction_series = pd.Series(model.predict(dataset), index = dataset.index, name = 'PredShare')
        results_dict[type] = prediction_series
    return results_dict

# %%
def log_params_mlflow_xgb(params, sampling_ratio):
    mlflow.log_param('max_depth', params['max_depth'])
    mlflow.log_param('colsample_bytree', params['colsample_bytree'])
    mlflow.log_param('learning_rate', params['learning_rate'])
    mlflow.log_param('n_estimators', params['n_estimators'])
    mlflow.log_param('best_ntree_limit', params['best_ntree_limit'])
    mlflow.log_param('subsample', params['subsample'])
    mlflow.log_param('sampling_ratio', sampling_ratio)

# %%
def log_params_mlflow_rf(params, sampling_ratio):
    mlflow.log_param('max_depth', params['max_depth'])
    mlflow.log_param('max_features', params['max_features'])
    mlflow.log_param('min_samples_split', params['min_samples_split'])
    mlflow.log_param('n_estimators', params['model__n_estimators'])
    mlflow.log_param('sampling_ratio', sampling_ratio)

# %%
def get_metrics(targets_real, targets_predicted):
    train_metrics = eval_metrics(targets_real['train'], targets_predicted['train'])
    test_metrics = eval_metrics(targets_real['test'], targets_predicted['test'])
    val_metrics = eval_metrics(targets_real['val'], targets_predicted['val'])
    return train_metrics, test_metrics, val_metrics

# %%
def log_metrics_mlflow(targets_real, targets_predicted, cv_score):
    train_metrics, test_metrics, val_metrics = get_metrics(targets_real, targets_predicted)

    mlflow.log_metric('rmse_train', train_metrics['rmse'])
    mlflow.log_metric('r2_train', train_metrics['r2'])
    mlflow.log_metric('rmse_test', test_metrics['rmse'])
    mlflow.log_metric('r2_test', test_metrics['r2'])
    mlflow.log_metric('rmse_val', val_metrics['rmse'])
    mlflow.log_metric('r2_val', val_metrics['r2'])
    mlflow.log_metric('rmse_cv', abs(cv_score))

# %%
def log_model_mlflow(model):
    mlflow.sklearn.log_model(model, 'model')

# %%
def log_df_mlflow(df, path):
    df.to_pickle(os.path.join(path, 'entry_dataframe.pkl'))
    mlflow.log_artifact(os.path.join(path, 'entry_dataframe.pkl'))

# %%
def display_metrics(targets_real, targets_predicted, cv_score):
    train_metrics, test_metrics, val_metrics = get_metrics(targets_real, targets_predicted)
    df_results = pd.DataFrame(
        {
            'Train': [train_metrics['rmse'], train_metrics['mae'], train_metrics['r2']],
            'CV': [cv_score * -1, np.nan, np.nan], 
            'Test': [test_metrics['rmse'], test_metrics['mae'], test_metrics['r2']], 
            'Validation': [val_metrics['rmse'], val_metrics['mae'], val_metrics['r2']],
        }, 
        index = ['RMSE', 'MAE', 'R2']
        )
    
    return df_results

# %%
def get_advanced_metrics(y_real, y_predict):

    results = pd.concat([y_real, y_predict], axis = 1)

    results_contenders = results[results['Share'] > 0]
    results_no_contenders = results[results['Share'] == 0]

    rmse_contenders = metrics.mean_squared_error(results_contenders['Share'], results_contenders['PredShare']) ** .5
    mae_no_contenders = metrics.mean_absolute_error(results_no_contenders['Share'], results_no_contenders['PredShare']) ** .5

    return rmse_contenders, mae_no_contenders

# %%
def log_advanced_metrics_mlflow(y_real, y_predict):
    rmse_contenders, mae_no_contenders = get_advanced_metrics(y_real, y_predict)
    mlflow.log_metric('rmse_cont', rmse_contenders)
    mlflow.log_metric('mae_no_cont', mae_no_contenders)

# %%
param_grid = {
    'max_depth': [6, 8, 10], 
    'colsample_bytree': [.5], 
    'learning_rate': [.1],
    'subsample': [1, .8, .6],
    'n_estimators': [1000]
    }

# %%
fit_params = {
    "early_stopping_rounds":20, 
    "eval_metric" : "rmse", 
    "eval_set" : [[X_test, y_test]]
}

# %%
with mlflow.start_run():
    model = xgb.XGBRegressor(random_state = 23, n_estimators = 1000)

    grid_model = GridSearchCV(model, param_grid, scoring = 'neg_root_mean_squared_error', n_jobs = -1, cv = 10)

    grid_model.fit(X_train, y_train, **fit_params)

    best_model, best_params, best_cv_score = retrieve_best(grid_model)

    predicted_targets = predict_model(best_model, datasets)

    log_params_mlflow_xgb(best_params, sampling_ratio)

    log_metrics_mlflow(real_targets, predicted_targets, best_cv_score)

    log_advanced_metrics_mlflow(real_targets['val'], predicted_targets['val'])

    log_model_mlflow(best_model)

    log_df_mlflow(df, dataframes_path)
# Out:
# [0]	validation_0-rmse:0.43678
# [1]	validation_0-rmse:0.39370
# [2]	validation_0-rmse:0.35507
# [3]	validation_0-rmse:0.32026
# [4]	validation_0-rmse:0.28897
# [5]	validation_0-rmse:0.26097
# [6]	validation_0-rmse:0.23569
# [7]	validation_0-rmse:0.21295
# [8]	validation_0-rmse:0.19279
# [9]	validation_0-rmse:0.17453
# [10]	validation_0-rmse:0.15815
# [11]	validation_0-rmse:0.14348
# [12]	validation_0-rmse:0.13044
# [13]	validation_0-rmse:0.11875
# [14]	validation_0-rmse:0.10829
# [15]	validation_0-rmse:0.09906
# [16]	validation_0-rmse:0.09085
# [17]	validation_0-rmse:0.08349
# [18]	validation_0-rmse:0.07697
# [19]	validation_0-rmse:0.07131
# [20]	validation_0-rmse:0.06641
# [21]	validation_0-rmse:0.06198
# [22]	validation_0-rmse:0.05819
# [23]	validation_0-rmse:0.05484
# [24]	validation_0-rmse:0.05196
# [25]	validation_0-rmse:0.04947
# [26]	validation_0-rmse:0.04747
# [27]	validation_0-rmse:0.04572
# [28]	validation_0-rmse:0.04417
# [29]	validation_0-rmse:0.04262
# [30]	validation_0-rmse:0.04145
# [31]	validation_0-rmse:0.04038
# [32]	validation_0-rmse:0.03947
# [33]	validation_0-rmse:0.03869
# [34]	validation_0-rmse:0.03806
# [35]	validation_0-rmse:0.03744
# [36]	validation_0-rmse:0.03708
# [37]	validation_0-rmse:0.03675
# [38]	validation_0-rmse:0.03643
# [39]	validation_0-rmse:0.03607
# [40]	validation_0-rmse:0.03587
# [41]	validation_0-rmse:0.03553
# [42]	validation_0-rmse:0.03529
# [43]	validation_0-rmse:0.03514
# [44]	validation_0-rmse:0.03501
# [45]	validation_0-rmse:0.03485
# [46]	validation_0-rmse:0.03462
# [47]	validation_0-rmse:0.03447
# [48]	validation_0-rmse:0.03433
# [49]	validation_0-rmse:0.03427
# [50]	validation_0-rmse:0.03418
# [51]	validation_0-rmse:0.03409
# [52]	validation_0-rmse:0.03406
# [53]	validation_0-rmse:0.03388
# [54]	validation_0-rmse:0.03381
# [55]	validation_0-rmse:0.03370
# [56]	validation_0-rmse:0.03363
# [57]	validation_0-rmse:0.03356
# [58]	validation_0-rmse:0.03354
# [59]	validation_0-rmse:0.03342
# [60]	validation_0-rmse:0.03325
# [61]	validation_0-rmse:0.03321
# [62]	validation_0-rmse:0.03315
# [63]	validation_0-rmse:0.03306
# [64]	validation_0-rmse:0.03302
# [65]	validation_0-rmse:0.03298
# [66]	validation_0-rmse:0.03294
# [67]	validation_0-rmse:0.03282
# [68]	validation_0-rmse:0.03278
# [69]	validation_0-rmse:0.03276
# [70]	validation_0-rmse:0.03268
# [71]	validation_0-rmse:0.03268
# [72]	validation_0-rmse:0.03261
# [73]	validation_0-rmse:0.03257
# [74]	validation_0-rmse:0.03257
# [75]	validation_0-rmse:0.03253
# [76]	validation_0-rmse:0.03253
# [77]	validation_0-rmse:0.03247
# [78]	validation_0-rmse:0.03244
# [79]	validation_0-rmse:0.03240
# [80]	validation_0-rmse:0.03236
# [81]	validation_0-rmse:0.03237
# [82]	validation_0-rmse:0.03234
# [83]	validation_0-rmse:0.03233
# [84]	validation_0-rmse:0.03230
# [85]	validation_0-rmse:0.03228
# [86]	validation_0-rmse:0.03224
# [87]	validation_0-rmse:0.03219
# [88]	validation_0-rmse:0.03218
# [89]	validation_0-rmse:0.03212
# [90]	validation_0-rmse:0.03212
# [91]	validation_0-rmse:0.03210
# [92]	validation_0-rmse:0.03200
# [93]	validation_0-rmse:0.03198
# [94]	validation_0-rmse:0.03193
# [95]	validation_0-rmse:0.03191
# [96]	validation_0-rmse:0.03188
# [97]	validation_0-rmse:0.03187
# [98]	validation_0-rmse:0.03187
# [99]	validation_0-rmse:0.03182
# [100]	validation_0-rmse:0.03179
# [101]	validation_0-rmse:0.03176
# [102]	validation_0-rmse:0.03176
# [103]	validation_0-rmse:0.03175
# [104]	validation_0-rmse:0.03172
# [105]	validation_0-rmse:0.03169
# [106]	validation_0-rmse:0.03170
# [107]	validation_0-rmse:0.03168
# [108]	validation_0-rmse:0.03167
# [109]	validation_0-rmse:0.03166
# [110]	validation_0-rmse:0.03160
# [111]	validation_0-rmse:0.03155
# [112]	validation_0-rmse:0.03153
# [113]	validation_0-rmse:0.03150
# [114]	validation_0-rmse:0.03150
# [115]	validation_0-rmse:0.03149
# [116]	validation_0-rmse:0.03145
# [117]	validation_0-rmse:0.03145
# [118]	validation_0-rmse:0.03145
# [119]	validation_0-rmse:0.03141
# [120]	validation_0-rmse:0.03141
# [121]	validation_0-rmse:0.03141
# [122]	validation_0-rmse:0.03140
# [123]	validation_0-rmse:0.03138
# [124]	validation_0-rmse:0.03138
# [125]	validation_0-rmse:0.03137
# [126]	validation_0-rmse:0.03136
# [127]	validation_0-rmse:0.03135
# [128]	validation_0-rmse:0.03132
# [129]	validation_0-rmse:0.03123
# [130]	validation_0-rmse:0.03120
# [131]	validation_0-rmse:0.03120
# [132]	validation_0-rmse:0.03120
# [133]	validation_0-rmse:0.03119
# [134]	validation_0-rmse:0.03118
# [135]	validation_0-rmse:0.03118
# [136]	validation_0-rmse:0.03115
# [137]	validation_0-rmse:0.03114
# [138]	validation_0-rmse:0.03113
# [139]	validation_0-rmse:0.03110
# [140]	validation_0-rmse:0.03109
# [141]	validation_0-rmse:0.03109
# [142]	validation_0-rmse:0.03107
# [143]	validation_0-rmse:0.03106
# [144]	validation_0-rmse:0.03104
# [145]	validation_0-rmse:0.03101
# [146]	validation_0-rmse:0.03101
# [147]	validation_0-rmse:0.03100
# [148]	validation_0-rmse:0.03098
# [149]	validation_0-rmse:0.03098
# [150]	validation_0-rmse:0.03097
# [151]	validation_0-rmse:0.03097
# [152]	validation_0-rmse:0.03095
# [153]	validation_0-rmse:0.03094
# [154]	validation_0-rmse:0.03095
# [155]	validation_0-rmse:0.03094
# [156]	validation_0-rmse:0.03093
# [157]	validation_0-rmse:0.03093
# [158]	validation_0-rmse:0.03093
# [159]	validation_0-rmse:0.03091
# [160]	validation_0-rmse:0.03090
# [161]	validation_0-rmse:0.03088
# [162]	validation_0-rmse:0.03088
# [163]	validation_0-rmse:0.03088
# [164]	validation_0-rmse:0.03087
# [165]	validation_0-rmse:0.03086
# [166]	validation_0-rmse:0.03085
# [167]	validation_0-rmse:0.03085
# [168]	validation_0-rmse:0.03084
# [169]	validation_0-rmse:0.03082
# [170]	validation_0-rmse:0.03082
# [171]	validation_0-rmse:0.03081
# [172]	validation_0-rmse:0.03080
# [173]	validation_0-rmse:0.03078
# [174]	validation_0-rmse:0.03077
# [175]	validation_0-rmse:0.03077
# [176]	validation_0-rmse:0.03075
# [177]	validation_0-rmse:0.03075
# [178]	validation_0-rmse:0.03074
# [179]	validation_0-rmse:0.03073
# [180]	validation_0-rmse:0.03073
# [181]	validation_0-rmse:0.03073
# [182]	validation_0-rmse:0.03072
# [183]	validation_0-rmse:0.03071
# [184]	validation_0-rmse:0.03071
# [185]	validation_0-rmse:0.03071
# [186]	validation_0-rmse:0.03072
# [187]	validation_0-rmse:0.03071
# [188]	validation_0-rmse:0.03070
# [189]	validation_0-rmse:0.03071
# [190]	validation_0-rmse:0.03070
# [191]	validation_0-rmse:0.03069
# [192]	validation_0-rmse:0.03070
# [193]	validation_0-rmse:0.03069
# [194]	validation_0-rmse:0.03069
# [195]	validation_0-rmse:0.03069
# [196]	validation_0-rmse:0.03069
# [197]	validation_0-rmse:0.03069
# [198]	validation_0-rmse:0.03069
# [199]	validation_0-rmse:0.03069
# [200]	validation_0-rmse:0.03069
# [201]	validation_0-rmse:0.03068
# [202]	validation_0-rmse:0.03069
# [203]	validation_0-rmse:0.03069
# [204]	validation_0-rmse:0.03068
# [205]	validation_0-rmse:0.03069
# [206]	validation_0-rmse:0.03068
# [207]	validation_0-rmse:0.03068
# [208]	validation_0-rmse:0.03066
# [209]	validation_0-rmse:0.03065
# [210]	validation_0-rmse:0.03065
# [211]	validation_0-rmse:0.03065
# [212]	validation_0-rmse:0.03065
# [213]	validation_0-rmse:0.03063
# [214]	validation_0-rmse:0.03063
# [215]	validation_0-rmse:0.03063
# [216]	validation_0-rmse:0.03062
# [217]	validation_0-rmse:0.03062
# [218]	validation_0-rmse:0.03062
# [219]	validation_0-rmse:0.03061
# [220]	validation_0-rmse:0.03061
# [221]	validation_0-rmse:0.03061
# [222]	validation_0-rmse:0.03060
# [223]	validation_0-rmse:0.03060
# [224]	validation_0-rmse:0.03060
# [225]	validation_0-rmse:0.03059
# [226]	validation_0-rmse:0.03059
# [227]	validation_0-rmse:0.03058
# [228]	validation_0-rmse:0.03058
# [229]	validation_0-rmse:0.03057
# [230]	validation_0-rmse:0.03058
# [231]	validation_0-rmse:0.03056
# [232]	validation_0-rmse:0.03056
# [233]	validation_0-rmse:0.03056
# [234]	validation_0-rmse:0.03055
# [235]	validation_0-rmse:0.03054
# [236]	validation_0-rmse:0.03054
# [237]	validation_0-rmse:0.03054
# [238]	validation_0-rmse:0.03053
# [239]	validation_0-rmse:0.03053
# [240]	validation_0-rmse:0.03053
# [241]	validation_0-rmse:0.03052
# [242]	validation_0-rmse:0.03052
# [243]	validation_0-rmse:0.03052
# [244]	validation_0-rmse:0.03051
# [245]	validation_0-rmse:0.03051
# [246]	validation_0-rmse:0.03051
# [247]	validation_0-rmse:0.03051
# [248]	validation_0-rmse:0.03051
# [249]	validation_0-rmse:0.03051
# [250]	validation_0-rmse:0.03051
# [251]	validation_0-rmse:0.03051
# [252]	validation_0-rmse:0.03050
# [253]	validation_0-rmse:0.03050
# [254]	validation_0-rmse:0.03049
# [255]	validation_0-rmse:0.03049
# [256]	validation_0-rmse:0.03049
# [257]	validation_0-rmse:0.03049
# [258]	validation_0-rmse:0.03049
# [259]	validation_0-rmse:0.03047
# [260]	validation_0-rmse:0.03047
# [261]	validation_0-rmse:0.03048
# [262]	validation_0-rmse:0.03047
# [263]	validation_0-rmse:0.03047
# [264]	validation_0-rmse:0.03046
# [265]	validation_0-rmse:0.03046
# [266]	validation_0-rmse:0.03046
# [267]	validation_0-rmse:0.03046
# [268]	validation_0-rmse:0.03045
# [269]	validation_0-rmse:0.03045
# [270]	validation_0-rmse:0.03045
# [271]	validation_0-rmse:0.03045
# [272]	validation_0-rmse:0.03045
# [273]	validation_0-rmse:0.03045
# [274]	validation_0-rmse:0.03045
# [275]	validation_0-rmse:0.03045
# [276]	validation_0-rmse:0.03044
# [277]	validation_0-rmse:0.03044
# [278]	validation_0-rmse:0.03044
# [279]	validation_0-rmse:0.03044
# [280]	validation_0-rmse:0.03043
# [281]	validation_0-rmse:0.03043
# [282]	validation_0-rmse:0.03043
# [283]	validation_0-rmse:0.03043
# [284]	validation_0-rmse:0.03043
# [285]	validation_0-rmse:0.03042
# [286]	validation_0-rmse:0.03042
# [287]	validation_0-rmse:0.03042
# [288]	validation_0-rmse:0.03042
# [289]	validation_0-rmse:0.03043
# [290]	validation_0-rmse:0.03043
# [291]	validation_0-rmse:0.03042
# [292]	validation_0-rmse:0.03042
# [293]	validation_0-rmse:0.03042
# [294]	validation_0-rmse:0.03042
# [295]	validation_0-rmse:0.03042
# [296]	validation_0-rmse:0.03042
# [297]	validation_0-rmse:0.03042
# [298]	validation_0-rmse:0.03042
# [299]	validation_0-rmse:0.03042
# [300]	validation_0-rmse:0.03042
# [301]	validation_0-rmse:0.03042
# [302]	validation_0-rmse:0.03042
# [303]	validation_0-rmse:0.03041
# [304]	validation_0-rmse:0.03041
# [305]	validation_0-rmse:0.03041
# [306]	validation_0-rmse:0.03041
# [307]	validation_0-rmse:0.03041
# [308]	validation_0-rmse:0.03040
# [309]	validation_0-rmse:0.03040
# [310]	validation_0-rmse:0.03039
# [311]	validation_0-rmse:0.03039
# [312]	validation_0-rmse:0.03039
# [313]	validation_0-rmse:0.03039
# [314]	validation_0-rmse:0.03039
# [315]	validation_0-rmse:0.03039
# [316]	validation_0-rmse:0.03039
# [317]	validation_0-rmse:0.03039
# [318]	validation_0-rmse:0.03039
# [319]	validation_0-rmse:0.03039
# [320]	validation_0-rmse:0.03038
# [321]	validation_0-rmse:0.03038
# [322]	validation_0-rmse:0.03037
# [323]	validation_0-rmse:0.03037
# [324]	validation_0-rmse:0.03037
# [325]	validation_0-rmse:0.03037
# [326]	validation_0-rmse:0.03037
# [327]	validation_0-rmse:0.03037
# [328]	validation_0-rmse:0.03037
# [329]	validation_0-rmse:0.03037
# [330]	validation_0-rmse:0.03037
# [331]	validation_0-rmse:0.03037
# [332]	validation_0-rmse:0.03037
# [333]	validation_0-rmse:0.03037
# [334]	validation_0-rmse:0.03037
# [335]	validation_0-rmse:0.03037
# [336]	validation_0-rmse:0.03037
# [337]	validation_0-rmse:0.03037
# [338]	validation_0-rmse:0.03037
# [339]	validation_0-rmse:0.03037
# [340]	validation_0-rmse:0.03037
# [341]	validation_0-rmse:0.03037
# [342]	validation_0-rmse:0.03037
# [343]	validation_0-rmse:0.03036
# [344]	validation_0-rmse:0.03036
# [345]	validation_0-rmse:0.03036
# [346]	validation_0-rmse:0.03036
# [347]	validation_0-rmse:0.03036
# [348]	validation_0-rmse:0.03036
# [349]	validation_0-rmse:0.03035
# [350]	validation_0-rmse:0.03035
# [351]	validation_0-rmse:0.03035
# [352]	validation_0-rmse:0.03035
# [353]	validation_0-rmse:0.03035
# [354]	validation_0-rmse:0.03035
# [355]	validation_0-rmse:0.03034
# [356]	validation_0-rmse:0.03034
# [357]	validation_0-rmse:0.03034
# [358]	validation_0-rmse:0.03034
# [359]	validation_0-rmse:0.03034
# [360]	validation_0-rmse:0.03034
# [361]	validation_0-rmse:0.03034
# [362]	validation_0-rmse:0.03034
# [363]	validation_0-rmse:0.03034
# [364]	validation_0-rmse:0.03033
# [365]	validation_0-rmse:0.03033
# [366]	validation_0-rmse:0.03033
# [367]	validation_0-rmse:0.03033
# [368]	validation_0-rmse:0.03033
# [369]	validation_0-rmse:0.03033
# [370]	validation_0-rmse:0.03033
# [371]	validation_0-rmse:0.03032
# [372]	validation_0-rmse:0.03032
# [373]	validation_0-rmse:0.03032
# [374]	validation_0-rmse:0.03032
# [375]	validation_0-rmse:0.03032
# [376]	validation_0-rmse:0.03032
# [377]	validation_0-rmse:0.03032
# [378]	validation_0-rmse:0.03032
# [379]	validation_0-rmse:0.03032
# [380]	validation_0-rmse:0.03032
# [381]	validation_0-rmse:0.03032
# [382]	validation_0-rmse:0.03032
# [383]	validation_0-rmse:0.03032
# [384]	validation_0-rmse:0.03032
# [385]	validation_0-rmse:0.03032
# [386]	validation_0-rmse:0.03032
# [387]	validation_0-rmse:0.03032
# [388]	validation_0-rmse:0.03032
# [389]	validation_0-rmse:0.03032
# [390]	validation_0-rmse:0.03031
# [391]	validation_0-rmse:0.03031
# [392]	validation_0-rmse:0.03031
# [393]	validation_0-rmse:0.03031
# [394]	validation_0-rmse:0.03031
# [395]	validation_0-rmse:0.03031
# [396]	validation_0-rmse:0.03031
# [397]	validation_0-rmse:0.03031
# [398]	validation_0-rmse:0.03031
# [399]	validation_0-rmse:0.03030
# [400]	validation_0-rmse:0.03030
# [401]	validation_0-rmse:0.03030
# [402]	validation_0-rmse:0.03030
# [403]	validation_0-rmse:0.03030
# [404]	validation_0-rmse:0.03030
# [405]	validation_0-rmse:0.03030
# [406]	validation_0-rmse:0.03030
# [407]	validation_0-rmse:0.03030
# [408]	validation_0-rmse:0.03030
# [409]	validation_0-rmse:0.03030
# [410]	validation_0-rmse:0.03030
# [411]	validation_0-rmse:0.03030
# [412]	validation_0-rmse:0.03030
# [413]	validation_0-rmse:0.03030
# [414]	validation_0-rmse:0.03030
# [415]	validation_0-rmse:0.03030
# [416]	validation_0-rmse:0.03029
# [417]	validation_0-rmse:0.03029
# [418]	validation_0-rmse:0.03029
# [419]	validation_0-rmse:0.03029
# [420]	validation_0-rmse:0.03029
# [421]	validation_0-rmse:0.03029
# [422]	validation_0-rmse:0.03029
# [423]	validation_0-rmse:0.03029
# [424]	validation_0-rmse:0.03028
# [425]	validation_0-rmse:0.03028
# [426]	validation_0-rmse:0.03028
# [427]	validation_0-rmse:0.03028
# [428]	validation_0-rmse:0.03028
# [429]	validation_0-rmse:0.03028
# [430]	validation_0-rmse:0.03028
# [431]	validation_0-rmse:0.03028
# [432]	validation_0-rmse:0.03028
# [433]	validation_0-rmse:0.03028
# [434]	validation_0-rmse:0.03028
# [435]	validation_0-rmse:0.03028
# [436]	validation_0-rmse:0.03028
# [437]	validation_0-rmse:0.03028
# [438]	validation_0-rmse:0.03028
# [439]	validation_0-rmse:0.03027
# [440]	validation_0-rmse:0.03028
# [441]	validation_0-rmse:0.03027
# [442]	validation_0-rmse:0.03027
# [443]	validation_0-rmse:0.03027
# [444]	validation_0-rmse:0.03027
# [445]	validation_0-rmse:0.03027
# [446]	validation_0-rmse:0.03027
# [447]	validation_0-rmse:0.03027
# [448]	validation_0-rmse:0.03027
# [449]	validation_0-rmse:0.03027
# [450]	validation_0-rmse:0.03027
# [451]	validation_0-rmse:0.03027
# [452]	validation_0-rmse:0.03027
# [453]	validation_0-rmse:0.03027
# [454]	validation_0-rmse:0.03026
# [455]	validation_0-rmse:0.03026
# [456]	validation_0-rmse:0.03026
# [457]	validation_0-rmse:0.03026
# [458]	validation_0-rmse:0.03026
# [459]	validation_0-rmse:0.03026
# [460]	validation_0-rmse:0.03026
# [461]	validation_0-rmse:0.03026
# [462]	validation_0-rmse:0.03026
# [463]	validation_0-rmse:0.03026
# [464]	validation_0-rmse:0.03026
# [465]	validation_0-rmse:0.03026
# [466]	validation_0-rmse:0.03026
# [467]	validation_0-rmse:0.03026
# [468]	validation_0-rmse:0.03026
# [469]	validation_0-rmse:0.03026
# [470]	validation_0-rmse:0.03026
# [471]	validation_0-rmse:0.03026
# [472]	validation_0-rmse:0.03026
# [473]	validation_0-rmse:0.03025
# [474]	validation_0-rmse:0.03025
# [475]	validation_0-rmse:0.03025
# [476]	validation_0-rmse:0.03025
# [477]	validation_0-rmse:0.03025
# [478]	validation_0-rmse:0.03026
# [479]	validation_0-rmse:0.03025
# [480]	validation_0-rmse:0.03025
# [481]	validation_0-rmse:0.03025
# [482]	validation_0-rmse:0.03025
# [483]	validation_0-rmse:0.03025
# [484]	validation_0-rmse:0.03025
# [485]	validation_0-rmse:0.03025
# [486]	validation_0-rmse:0.03025
# [487]	validation_0-rmse:0.03025
# [488]	validation_0-rmse:0.03025
# [489]	validation_0-rmse:0.03025
# [490]	validation_0-rmse:0.03025
# [491]	validation_0-rmse:0.03025
# [492]	validation_0-rmse:0.03025
# [493]	validation_0-rmse:0.03025
# [494]	validation_0-rmse:0.03025
# [495]	validation_0-rmse:0.03025
# [496]	validation_0-rmse:0.03025
# [497]	validation_0-rmse:0.03025
# [498]	validation_0-rmse:0.03025
# [499]	validation_0-rmse:0.03025
# [500]	validation_0-rmse:0.03025
# [501]	validation_0-rmse:0.03025
# [502]	validation_0-rmse:0.03025
# [503]	validation_0-rmse:0.03025
# [504]	validation_0-rmse:0.03025
# [505]	validation_0-rmse:0.03025
# [506]	validation_0-rmse:0.03024
# [507]	validation_0-rmse:0.03024
# [508]	validation_0-rmse:0.03024
# [509]	validation_0-rmse:0.03024
# [510]	validation_0-rmse:0.03024
# [511]	validation_0-rmse:0.03024
# [512]	validation_0-rmse:0.03024
# [513]	validation_0-rmse:0.03024
# [514]	validation_0-rmse:0.03024
# [515]	validation_0-rmse:0.03024
# [516]	validation_0-rmse:0.03024
# [517]	validation_0-rmse:0.03024
# [518]	validation_0-rmse:0.03024
# [519]	validation_0-rmse:0.03024
# [520]	validation_0-rmse:0.03024
# [521]	validation_0-rmse:0.03024
# [522]	validation_0-rmse:0.03024
# [523]	validation_0-rmse:0.03024
# [524]	validation_0-rmse:0.03024
# [525]	validation_0-rmse:0.03024
# [526]	validation_0-rmse:0.03024
# [527]	validation_0-rmse:0.03024
# [528]	validation_0-rmse:0.03024
# [529]	validation_0-rmse:0.03024
# [530]	validation_0-rmse:0.03023
# [531]	validation_0-rmse:0.03023
# [532]	validation_0-rmse:0.03023
# [533]	validation_0-rmse:0.03023
# [534]	validation_0-rmse:0.03023
# [535]	validation_0-rmse:0.03023
# [536]	validation_0-rmse:0.03023
# [537]	validation_0-rmse:0.03023
# [538]	validation_0-rmse:0.03023
# [539]	validation_0-rmse:0.03023
# [540]	validation_0-rmse:0.03023
# [541]	validation_0-rmse:0.03023
# [542]	validation_0-rmse:0.03023
# [543]	validation_0-rmse:0.03023
# [544]	validation_0-rmse:0.03023
# [545]	validation_0-rmse:0.03023
# [546]	validation_0-rmse:0.03023
# [547]	validation_0-rmse:0.03023
# [548]	validation_0-rmse:0.03023
# [549]	validation_0-rmse:0.03023
# [550]	validation_0-rmse:0.03023
# [551]	validation_0-rmse:0.03023
# [552]	validation_0-rmse:0.03023
# [553]	validation_0-rmse:0.03023
# [554]	validation_0-rmse:0.03023
# [555]	validation_0-rmse:0.03023
# [556]	validation_0-rmse:0.03023
# [557]	validation_0-rmse:0.03023
# [558]	validation_0-rmse:0.03023
# [559]	validation_0-rmse:0.03023
# [560]	validation_0-rmse:0.03023
# [561]	validation_0-rmse:0.03023
# [562]	validation_0-rmse:0.03023
# [563]	validation_0-rmse:0.03023
# [564]	validation_0-rmse:0.03023
# [565]	validation_0-rmse:0.03023
# [566]	validation_0-rmse:0.03023
# [567]	validation_0-rmse:0.03023
# [568]	validation_0-rmse:0.03023
# [569]	validation_0-rmse:0.03023
# [570]	validation_0-rmse:0.03022
# [571]	validation_0-rmse:0.03022
# [572]	validation_0-rmse:0.03022
# [573]	validation_0-rmse:0.03022
# [574]	validation_0-rmse:0.03022
# [575]	validation_0-rmse:0.03022
# [576]	validation_0-rmse:0.03022
# [577]	validation_0-rmse:0.03022
# [578]	validation_0-rmse:0.03022
# [579]	validation_0-rmse:0.03022
# [580]	validation_0-rmse:0.03022
# [581]	validation_0-rmse:0.03022
# [582]	validation_0-rmse:0.03022
# [583]	validation_0-rmse:0.03022
# [584]	validation_0-rmse:0.03022
# [585]	validation_0-rmse:0.03022
# [586]	validation_0-rmse:0.03022
# [587]	validation_0-rmse:0.03022
# [588]	validation_0-rmse:0.03022
# [589]	validation_0-rmse:0.03022
# [590]	validation_0-rmse:0.03022
# [591]	validation_0-rmse:0.03022
# [592]	validation_0-rmse:0.03022
# [593]	validation_0-rmse:0.03022
# [594]	validation_0-rmse:0.03022
# [595]	validation_0-rmse:0.03022
# [596]	validation_0-rmse:0.03022
# [597]	validation_0-rmse:0.03022
# [598]	validation_0-rmse:0.03022
# [599]	validation_0-rmse:0.03022
# [600]	validation_0-rmse:0.03022
# [601]	validation_0-rmse:0.03022
# [602]	validation_0-rmse:0.03022
# [603]	validation_0-rmse:0.03022
# [604]	validation_0-rmse:0.03022
# [605]	validation_0-rmse:0.03022
# [606]	validation_0-rmse:0.03022
# [607]	validation_0-rmse:0.03022
# [608]	validation_0-rmse:0.03022
# [609]	validation_0-rmse:0.03022
# [610]	validation_0-rmse:0.03022
# 2022/04/18 14:43:01 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: C:\Users\marcr\AppData\Local\Temp\tmp6m_4kv5c\model\model.pkl, flavor: sklearn), fall back to return ['scikit-learn==1.0.1', 'cloudpickle==2.0.0']. Set logging level to DEBUG to see the full traceback.

# %%
grid_model.best_estimator_.best_ntree_limit
# Out:
# 591

# %%
display_metrics(real_targets, predicted_targets, best_cv_score)
# Out:
#          Train        CV      Test  Validation
# RMSE  0.000665  0.030058  0.030219    0.033100
# MAE   0.000318       NaN  0.008304    0.005636
# R2    0.999970       NaN  0.932534    0.657858

# %%
def get_val_results(real_val_y, pred_val_y, players_series):

    players_series_val = players_series[players_series.index.get_level_values(1) > 2015]
    results_val = pd.concat([players_series_val, real_val_y, pred_val_y], axis = 1)
    
    results_val_contenders = results_val[results_val['Share'] > 0]
    results_val_no_contenders = results_val[results_val['Share'] == 0]

    return results_val_contenders, results_val_no_contenders

# %%
def display_val_results(results_val_contenders, results_val_no_contenders):
    print(f'Contenders Results:')
    for season in set(results_val_contenders.index.get_level_values(1)):
        display(results_val_contenders.loc[pd.IndexSlice[:, season], :].sort_values(by = 'Share', ascending = False))

    print(f'No contenders results:')
    display(results_val_no_contenders[results_val_no_contenders['PredShare'] > 0])

# %%
contenders_df, no_contenders_df = get_val_results(real_targets['val'], predicted_targets['val'], pipe['DropPlayers'].players_list_)

# %%
display_val_results(contenders_df, no_contenders_df)
# Out:
# Contenders Results:
#                        Player  Share  PredShare
# Rk  Season
# 105 2016        Stephen Curry  1.000   0.964236
# 263 2016        Kawhi Leonard  0.484   0.332870
# 222 2016         LeBron James  0.482   0.432793
# 452 2016    Russell Westbrook  0.371   0.191129
# 126 2016         Kevin Durant  0.112   0.605469
# 348 2016           Chris Paul  0.082   0.164420
# 167 2016       Draymond Green  0.038   0.053914
# 266 2016       Damian Lillard  0.020   0.033292
# 178 2016         James Harden  0.007   0.324091
# 273 2016           Kyle Lowry  0.005   0.129491
#                            Player  Share  PredShare
# Rk  Season
# 458 2017        Russell Westbrook  0.879   0.559861
# 173 2017             James Harden  0.746   0.467868
# 261 2017            Kawhi Leonard  0.495   0.500365
# 221 2017             LeBron James  0.330   0.344950
# 425 2017            Isaiah Thomas  0.080   0.338275
# 98  2017            Stephen Curry  0.051   0.460013
# 16  2017    Giannis Antetokounmpo  0.007   0.090593
# 453 2017                John Wall  0.007   0.096531
# 100 2017            Anthony Davis  0.002   0.190594
# 119 2017             Kevin Durant  0.002   0.450008
# 108 2017            DeMar DeRozan  0.001   0.084384
#                            Player  Share  PredShare
# Rk  Season
# 195 2018             James Harden  0.955   0.867224
# 249 2018             LeBron James  0.731   0.435640
# 122 2018            Anthony Davis  0.441   0.222637
# 298 2018           Damian Lillard  0.205   0.228861
# 508 2018        Russell Westbrook  0.075   0.258220
# 16  2018    Giannis Antetokounmpo  0.074   0.162859
# 143 2018             Kevin Durant  0.065   0.367809
# 130 2018            DeMar DeRozan  0.032   0.035444
# 7   2018        LaMarcus Aldridge  0.006   0.103441
# 79  2018             Jimmy Butler  0.005   0.027280
# 120 2018            Stephen Curry  0.005   0.089662
# 147 2018              Joel Embiid  0.004   0.047623
# 382 2018           Victor Oladipo  0.002   0.058495
#                            Player  Share  PredShare
# Rk  Season
# 18  2019    Giannis Antetokounmpo  0.932   0.619208
# 207 2019             James Harden  0.768   0.583388
# 184 2019              Paul George  0.352   0.141576
# 270 2019             Nikola Jokić  0.210   0.176943
# 124 2019            Stephen Curry  0.173   0.245602
# 305 2019           Damian Lillard  0.068   0.196572
# 155 2019              Joel Embiid  0.049   0.191379
# 150 2019             Kevin Durant  0.025   0.361476
# 301 2019            Kawhi Leonard  0.013   0.234243
# 506 2019        Russell Westbrook  0.008   0.124920
# 188 2019              Rudy Gobert  0.001   0.083737
# 259 2019             LeBron James  0.001   0.201515
#                            Player  Share  PredShare
# Rk  Season
# 13  2020    Giannis Antetokounmpo  0.952   0.668879
# 251 2020             LeBron James  0.746   0.519328
# 199 2020             James Harden  0.363   0.465355
# 134 2020              Luka Dončić  0.198   0.364993
# 294 2020            Kawhi Leonard  0.166   0.307436
# 123 2020            Anthony Davis  0.081   0.496000
# 396 2020               Chris Paul  0.026  -0.001702
# 297 2020           Damian Lillard  0.023   0.283165
# 262 2020             Nikola Jokić  0.018   0.147684
# 449 2020            Pascal Siakam  0.017   0.014858
# 82  2020             Jimmy Butler  0.009   0.029272
# 464 2020             Jayson Tatum  0.001   0.014192
#                            Player  Share  PredShare
# Rk  Season
# 263 2021             Nikola Jokić  0.961   0.520558
# 146 2021              Joel Embiid  0.580   0.167409
# 116 2021            Stephen Curry  0.449   0.358516
# 12  2021    Giannis Antetokounmpo  0.345   0.377677
# 396 2021               Chris Paul  0.138   0.025152
# 130 2021              Luka Dončić  0.042   0.395176
# 297 2021           Damian Lillard  0.038   0.364448
# 421 2021            Julius Randle  0.020   0.065629
# 439 2021             Derrick Rose  0.010  -0.000098
# 180 2021              Rudy Gobert  0.008   0.114774
# 517 2021        Russell Westbrook  0.005   0.005503
# 457 2021              Ben Simmons  0.003   0.006630
# 201 2021             James Harden  0.001   0.142103
# 252 2021             LeBron James  0.001   0.169734
# 293 2021            Kawhi Leonard  0.001   0.138921
# No contenders results:
#                        Player  Share  PredShare
# Rk  Season
# 2   2016         Jordan Adams    0.0   0.012304
# 4   2016        Arron Afflalo    0.0   0.000032
# 5   2016        Alexis Ajinça    0.0   0.000017
# 7   2016    LaMarcus Aldridge    0.0   0.022903
# 8   2016      Cliff Alexander    0.0   0.000018
# ...                       ...    ...        ...
# 535 2021    Robert Woodard II    0.0   0.000050
# 536 2021         Delon Wright    0.0   0.000023
# 538 2021           Trae Young    0.0   0.058910
# 539 2021          Cody Zeller    0.0   0.000222
# 540 2021          Ivica Zubac    0.0   0.002152
#
# [2117 rows x 3 columns]

# %%
no_contenders_df[no_contenders_df['PredShare'] > 0.1]
# Out:
#                         Player  Share  PredShare
# Rk  Season
# 97  2016      DeMarcus Cousins    0.0   0.100982
# 453 2016      Hassan Whiteside    0.0   0.116006
# 156 2017           Rudy Gobert    0.0   0.115771
# 266 2017        Damian Lillard    0.0   0.130551
# 434 2017    Karl-Anthony Towns    0.0   0.136015
# 240 2018          Kyrie Irving    0.0   0.173408
# 525 2020            Trae Young    0.0   0.155214
# 38  2021          Bradley Beal    0.0   0.122247
# 58  2021          Devin Booker    0.0   0.106074
# 140 2021          Kevin Durant    0.0   0.142349
# 244 2021          Kyrie Irving    0.0   0.142869

# %%
top_features = pd.DataFrame(best_model.feature_importances_, index = X_train.columns, columns = ['Importance']).sort_values('Importance', ascending = False)

# %%
top_features[top_features['Importance'] > 0.005]
# Out:
#               Importance
# WS              0.288776
# PER             0.148157
# VORP            0.063477
# WS/48           0.058956
# %W              0.046761
# PTS_pg          0.026245
# FGA_tot         0.017838
# BPM             0.014587
# PTS_tot_rank    0.014569
# TOV_pg          0.011319
# FGA_pg_rank     0.011061
# PTS_tot         0.009277
# DWS             0.009043
# WS_rank         0.009030
# FG_pg           0.008918
# 2P_tot          0.008808
# 3P_pg           0.008418
# %G              0.008240
# TOV_tot         0.007678
# MP_tot          0.007647
# DRB_pg          0.007436
# FTr             0.006187
# AST%            0.006140
# FT_tot          0.005580
# FTA_pg          0.005181
# BLK_pg          0.005176
# 2PA_pg          0.005095
