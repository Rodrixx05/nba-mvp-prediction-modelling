# %%
import pandas as pd
import numpy as np
import plotly.express as px

from jupyter_dash import JupyterDash
from dash import dash, dcc, html
from dash.dependencies import Input, Output


import os

# %%
dataframes_path = os.path.join(os.getcwd(), 'dataframes')

# %%
df = pd.read_pickle(os.path.join(dataframes_path, 'complete_stats.pkl'))

# %%
df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21655 entries, 0 to 21654
# Data columns (total 138 columns):
#  #    Column        Dtype
# ---   ------        -----
#  0    Rk            int64
#  1    Player        object
#  2    Pos           object
#  3    Age           int64
#  4    Tm            object
#  5    G             int64
#  6    GS            int64
#  7    MP_pg         float64
#  8    FG_pg         float64
#  9    FGA_pg        float64
#  10   FG%           float64
#  11   3P_pg         float64
#  12   3PA_pg        float64
#  13   3P%           float64
#  14   2P_pg         float64
#  15   2PA_pg        float64
#  16   2P%           float64
#  17   eFG%          float64
#  18   FT_pg         float64
#  19   FTA_pg        float64
#  20   FT%           float64
#  21   ORB_pg        float64
#  22   DRB_pg        float64
#  23   TRB_pg        float64
#  24   AST_pg        float64
#  25   STL_pg        float64
#  26   BLK_pg        float64
#  27   TOV_pg        float64
#  28   PF_pg         float64
#  29   PTS_pg        float64
#  30   Season        int64
#  31   MP_tot        int64
#  32   FG_tot        int64
#  33   FGA_tot       int64
#  34   3P_tot        int64
#  35   3PA_tot       int64
#  36   2P_tot        int64
#  37   2PA_tot       int64
#  38   FT_tot        int64
#  39   FTA_tot       int64
#  40   ORB_tot       int64
#  41   DRB_tot       int64
#  42   TRB_tot       int64
#  43   AST_tot       int64
#  44   STL_tot       int64
#  45   BLK_tot       int64
#  46   TOV_tot       int64
#  47   PF_tot        int64
#  48   PTS_tot       int64
#  49   PER           float64
#  50   TS%           float64
#  51   3PAr          float64
#  52   FTr           float64
#  53   ORB%          float64
#  54   DRB%          float64
#  55   TRB%          float64
#  56   AST%          float64
#  57   STL%          float64
#  58   BLK%          float64
#  59   TOV%          float64
#  60   USG%          float64
#  61   OWS           float64
#  62   DWS           float64
#  63   WS            float64
#  64   WS/48         float64
#  65   OBPM          float64
#  66   DBPM          float64
#  67   BPM           float64
#  68   VORP          float64
#  69   %W            float64
#  70   GT            int32
#  71   %G            float64
#  72   MP_pg_rank    int32
#  73   FG_pg_rank    int32
#  74   FGA_pg_rank   int32
#  75   FG%_rank      int32
#  76   3P_pg_rank    int32
#  77   3PA_pg_rank   int32
#  78   3P%_rank      int32
#  79   2P_pg_rank    int32
#  80   2PA_pg_rank   int32
#  81   2P%_rank      int32
#  82   eFG%_rank     int32
#  83   FT_pg_rank    int32
#  84   FTA_pg_rank   int32
#  85   FT%_rank      int32
#  86   ORB_pg_rank   int32
#  87   DRB_pg_rank   int32
#  88   TRB_pg_rank   int32
#  89   AST_pg_rank   int32
#  90   STL_pg_rank   int32
#  91   BLK_pg_rank   int32
#  92   TOV_pg_rank   int32
#  93   PF_pg_rank    int32
#  94   PTS_pg_rank   int32
#  95   MP_tot_rank   int32
#  96   FG_tot_rank   int32
#  97   FGA_tot_rank  int32
#  98   3P_tot_rank   int32
#  99   3PA_tot_rank  int32
#  100  2P_tot_rank   int32
#  101  2PA_tot_rank  int32
#  102  FT_tot_rank   int32
#  103  FTA_tot_rank  int32
#  104  ORB_tot_rank  int32
#  105  DRB_tot_rank  int32
#  106  TRB_tot_rank  int32
#  107  AST_tot_rank  int32
#  108  STL_tot_rank  int32
#  109  BLK_tot_rank  int32
#  110  TOV_tot_rank  int32
#  111  PF_tot_rank   int32
#  112  PTS_tot_rank  int32
#  113  PER_rank      int32
#  114  TS%_rank      int32
#  115  3PAr_rank     int32
#  116  FTr_rank      int32
#  117  ORB%_rank     int32
#  118  DRB%_rank     int32
#  119  TRB%_rank     int32
#  120  AST%_rank     int32
#  121  STL%_rank     int32
#  122  BLK%_rank     int32
#  123  TOV%_rank     int32
#  124  USG%_rank     int32
#  125  OWS_rank      int32
#  126  DWS_rank      int32
#  127  WS_rank       int32
#  128  WS/48_rank    int32
#  129  OBPM_rank     int32
#  130  DBPM_rank     int32
#  131  BPM_rank      int32
#  132  VORP_rank     int32
#  133  %W_rank       int32
#  134  %GS           float64
#  135  Votes         int32
#  136  Share         float64
#  137  MaxVotes      int32
# dtypes: float64(47), int32(65), int64(23), object(3)
# memory usage: 17.4+ MB

# %%
def check_rk_season(df, rk_season_pairs):
    return df.apply(lambda x: (x['Rk'], x['Season']) in rk_season_pairs, axis = 1)

# %%
def drop_players_multiteams(df):
    df_tot = df[df['Tm'] == 'TOT']
    rk_season_pairs = list(zip(df_tot['Rk'], df_tot['Season']))
    df_tot_full = df[check_rk_season(df, rk_season_pairs)]
    drop_index = df_tot_full[df_tot_full['Tm'] != 'TOT'].index
    return df.drop(drop_index).reset_index(drop = True)

# %%
df = drop_players_multiteams(df)

# %%
df.describe()
# Out:
#                  Rk           Age             G            GS         MP_pg  \
# count  17683.000000  17683.000000  17683.000000  17683.000000  17683.000000
# mean     216.510321     26.659221     54.100040     25.148448     20.510897
# std      130.322040      4.078730     25.217314     29.720575     10.104615
# min        1.000000     18.000000      1.000000    -10.000000      0.000000
# 25%      106.000000     23.000000     35.000000      0.000000     12.100000
# 50%      211.000000     26.000000     62.000000     10.000000     20.000000
# 75%      317.500000     29.000000     77.000000     51.000000     29.000000
# max      540.000000     44.000000     85.000000     83.000000     43.700000
#
#               FG_pg        FGA_pg           FG%         3P_pg        3PA_pg  \
# count  17683.000000  17683.000000  17683.000000  17683.000000  17683.000000
# mean       3.210355      7.039173      0.441750      0.448504      1.299434
# std        2.284105      4.709932      0.094254      0.636592      1.682514
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.400000      3.300000      0.405000      0.000000      0.000000
# 50%        2.700000      5.900000      0.446000      0.100000      0.500000
# 75%        4.600000      9.900000      0.488000      0.700000      2.100000
# max       13.400000     27.800000      1.000000      5.300000     13.200000
#
#        ...    WS/48_rank     OBPM_rank     DBPM_rank      BPM_rank  \
# count  ...  17683.000000  17683.000000  17683.000000  17683.000000
# mean   ...    109.805293     64.566194     39.448001     71.441215
# std    ...     56.590689     28.557129     14.085333     32.326389
# min    ...      1.000000      1.000000      1.000000      1.000000
# 25%    ...     68.000000     45.000000     31.000000     50.000000
# 50%    ...    106.000000     63.000000     39.000000     70.000000
# 75%    ...    148.000000     82.000000     48.000000     91.000000
# max    ...    287.000000    164.000000     98.000000    183.000000
#
#           VORP_rank       %W_rank           %GS         Votes         Share  \
# count  17683.000000  17683.000000  17683.000000  17683.000000  17683.000000
# mean      42.719900     28.788837      0.350863      6.415597      0.006084
# std       12.282598     22.199965      0.462984     64.303990      0.059236
# min        1.000000      1.000000     -1.000000      0.000000      0.000000
# 25%       37.000000     10.000000      0.000000      0.000000      0.000000
# 50%       46.000000     24.000000      0.195000      0.000000      0.000000
# 75%       51.000000     44.000000      0.839500      0.000000      0.000000
# max       69.000000     98.000000      1.000000   1310.000000      1.000000
#
#            MaxVotes
# count  17683.000000
# mean    1070.038851
# std      208.777846
# min      221.000000
# 25%      980.000000
# 50%     1150.000000
# 75%     1230.000000
# max     1310.000000
#
# [8 rows x 135 columns]

# %%
df_corr = df.corr()

# %%
df_corr[(df_corr > 0.99) & (df_corr < 1)].dropna(how = 'all').dropna(how = 'all', axis = 1)
# Out:
#                 FG_tot   3P_tot  3PA_tot    2P_tot   2PA_tot   PTS_tot  \
# FG_tot             NaN      NaN      NaN       NaN       NaN  0.992847
# 3P_tot             NaN      NaN  0.99141       NaN       NaN       NaN
# 3PA_tot            NaN  0.99141      NaN       NaN       NaN       NaN
# 2P_tot             NaN      NaN      NaN       NaN  0.992516       NaN
# 2PA_tot            NaN      NaN      NaN  0.992516       NaN       NaN
# PTS_tot       0.992847      NaN      NaN       NaN       NaN       NaN
# FGA_tot_rank       NaN      NaN      NaN       NaN       NaN       NaN
# PTS_tot_rank       NaN      NaN      NaN       NaN       NaN       NaN
#
#               FGA_tot_rank  PTS_tot_rank
# FG_tot                 NaN           NaN
# 3P_tot                 NaN           NaN
# 3PA_tot                NaN           NaN
# 2P_tot                 NaN           NaN
# 2PA_tot                NaN           NaN
# PTS_tot                NaN           NaN
# FGA_tot_rank           NaN      0.992695
# PTS_tot_rank      0.992695           NaN

# %%
df.drop(columns = ['FG_tot', '3PA_tot', '2PA_tot', 'FGA_tot_rank'], inplace = True)

# %%
df['Contender'] = df['Share'] > 0

# %%
df.loc[df.groupby('Season')['Share'].idxmax(), 'Contender'] = 'MVP'

# %%
def corr_share(df, stat):
    fig = px.scatter(df, x = stat, y = 'Share', color = 'Contender', hover_name = 'Player', hover_data = ['Season'])
    fig.show()

# %%
corr_share(df, 'PTS_pg')

# %%
app = JupyterDash(__name__)
app.layout = html.Div([
    html.H1('Correlation between a chosen stat and MVP votes', style = {'color': 'white'}),
    dcc.Graph(id = 'graph', figure = {}),
    html.Label('Player stat'),
    dcc.Dropdown(id = 'dropdown', options = df.columns, value = 'PTS_pg')
])

@app.callback(Output('graph', 'figure'), Input('dropdown', 'value'))

def update_graph(value):
    fig = px.scatter(df, x = value, y = 'Share', color = 'Contender', hover_name = 'Player', hover_data = ['Season'])
    return fig

app.run_server(mode = 'inline')
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
