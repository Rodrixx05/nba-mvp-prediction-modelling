# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import os

# %%
dataframes_path = os.path.join(os.getcwd(), 'dataframes')

# %%
df = pd.read_pickle(os.path.join(dataframes_path, 'complete_stats.pkl'))

# %%
df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21655 entries, 0 to 21654
# Data columns (total 138 columns):
#  #    Column        Dtype
# ---   ------        -----
#  0    Rk            int64
#  1    Player        object
#  2    Pos           object
#  3    Age           int64
#  4    Tm            object
#  5    G             int64
#  6    GS            int64
#  7    MP_pg         float64
#  8    FG_pg         float64
#  9    FGA_pg        float64
#  10   FG%           float64
#  11   3P_pg         float64
#  12   3PA_pg        float64
#  13   3P%           float64
#  14   2P_pg         float64
#  15   2PA_pg        float64
#  16   2P%           float64
#  17   eFG%          float64
#  18   FT_pg         float64
#  19   FTA_pg        float64
#  20   FT%           float64
#  21   ORB_pg        float64
#  22   DRB_pg        float64
#  23   TRB_pg        float64
#  24   AST_pg        float64
#  25   STL_pg        float64
#  26   BLK_pg        float64
#  27   TOV_pg        float64
#  28   PF_pg         float64
#  29   PTS_pg        float64
#  30   Season        int64
#  31   MP_tot        int64
#  32   FG_tot        int64
#  33   FGA_tot       int64
#  34   3P_tot        int64
#  35   3PA_tot       int64
#  36   2P_tot        int64
#  37   2PA_tot       int64
#  38   FT_tot        int64
#  39   FTA_tot       int64
#  40   ORB_tot       int64
#  41   DRB_tot       int64
#  42   TRB_tot       int64
#  43   AST_tot       int64
#  44   STL_tot       int64
#  45   BLK_tot       int64
#  46   TOV_tot       int64
#  47   PF_tot        int64
#  48   PTS_tot       int64
#  49   PER           float64
#  50   TS%           float64
#  51   3PAr          float64
#  52   FTr           float64
#  53   ORB%          float64
#  54   DRB%          float64
#  55   TRB%          float64
#  56   AST%          float64
#  57   STL%          float64
#  58   BLK%          float64
#  59   TOV%          float64
#  60   USG%          float64
#  61   OWS           float64
#  62   DWS           float64
#  63   WS            float64
#  64   WS/48         float64
#  65   OBPM          float64
#  66   DBPM          float64
#  67   BPM           float64
#  68   VORP          float64
#  69   %W            float64
#  70   GT            int32
#  71   %G            float64
#  72   MP_pg_rank    int32
#  73   FG_pg_rank    int32
#  74   FGA_pg_rank   int32
#  75   FG%_rank      int32
#  76   3P_pg_rank    int32
#  77   3PA_pg_rank   int32
#  78   3P%_rank      int32
#  79   2P_pg_rank    int32
#  80   2PA_pg_rank   int32
#  81   2P%_rank      int32
#  82   eFG%_rank     int32
#  83   FT_pg_rank    int32
#  84   FTA_pg_rank   int32
#  85   FT%_rank      int32
#  86   ORB_pg_rank   int32
#  87   DRB_pg_rank   int32
#  88   TRB_pg_rank   int32
#  89   AST_pg_rank   int32
#  90   STL_pg_rank   int32
#  91   BLK_pg_rank   int32
#  92   TOV_pg_rank   int32
#  93   PF_pg_rank    int32
#  94   PTS_pg_rank   int32
#  95   MP_tot_rank   int32
#  96   FG_tot_rank   int32
#  97   FGA_tot_rank  int32
#  98   3P_tot_rank   int32
#  99   3PA_tot_rank  int32
#  100  2P_tot_rank   int32
#  101  2PA_tot_rank  int32
#  102  FT_tot_rank   int32
#  103  FTA_tot_rank  int32
#  104  ORB_tot_rank  int32
#  105  DRB_tot_rank  int32
#  106  TRB_tot_rank  int32
#  107  AST_tot_rank  int32
#  108  STL_tot_rank  int32
#  109  BLK_tot_rank  int32
#  110  TOV_tot_rank  int32
#  111  PF_tot_rank   int32
#  112  PTS_tot_rank  int32
#  113  PER_rank      int32
#  114  TS%_rank      int32
#  115  3PAr_rank     int32
#  116  FTr_rank      int32
#  117  ORB%_rank     int32
#  118  DRB%_rank     int32
#  119  TRB%_rank     int32
#  120  AST%_rank     int32
#  121  STL%_rank     int32
#  122  BLK%_rank     int32
#  123  TOV%_rank     int32
#  124  USG%_rank     int32
#  125  OWS_rank      int32
#  126  DWS_rank      int32
#  127  WS_rank       int32
#  128  WS/48_rank    int32
#  129  OBPM_rank     int32
#  130  DBPM_rank     int32
#  131  BPM_rank      int32
#  132  VORP_rank     int32
#  133  %W_rank       int32
#  134  %GS           float64
#  135  Votes         int32
#  136  Share         float64
#  137  MaxVotes      int32
# dtypes: float64(47), int32(65), int64(23), object(3)
# memory usage: 17.4+ MB

# %%
def check_rk_season(df, rk_season_pairs):
    return df.apply(lambda x: (x['Rk'], x['Season']) in rk_season_pairs, axis = 1)

# %%
def drop_players_multiteams(df):
    df_tot = df[df['Tm'] == 'TOT']
    rk_season_pairs = list(zip(df_tot['Rk'], df_tot['Season']))
    df_tot_full = df[check_rk_season(df, rk_season_pairs)]
    drop_index = df_tot_full[df_tot_full['Tm'] != 'TOT'].index
    return df.drop(drop_index).reset_index(drop = True)

# %%
df = drop_players_multiteams(df)

# %%
df.describe()
# Out:
#                  Rk           Age             G            GS         MP_pg  \
# count  17683.000000  17683.000000  17683.000000  17683.000000  17683.000000
# mean     216.510321     26.659221     54.100040     25.148448     20.510897
# std      130.322040      4.078730     25.217314     29.720575     10.104615
# min        1.000000     18.000000      1.000000    -10.000000      0.000000
# 25%      106.000000     23.000000     35.000000      0.000000     12.100000
# 50%      211.000000     26.000000     62.000000     10.000000     20.000000
# 75%      317.500000     29.000000     77.000000     51.000000     29.000000
# max      540.000000     44.000000     85.000000     83.000000     43.700000
#
#               FG_pg        FGA_pg           FG%         3P_pg        3PA_pg  \
# count  17683.000000  17683.000000  17683.000000  17683.000000  17683.000000
# mean       3.210355      7.039173      0.441750      0.448504      1.299434
# std        2.284105      4.709932      0.094254      0.636592      1.682514
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.400000      3.300000      0.405000      0.000000      0.000000
# 50%        2.700000      5.900000      0.446000      0.100000      0.500000
# 75%        4.600000      9.900000      0.488000      0.700000      2.100000
# max       13.400000     27.800000      1.000000      5.300000     13.200000
#
#        ...    WS/48_rank     OBPM_rank     DBPM_rank      BPM_rank  \
# count  ...  17683.000000  17683.000000  17683.000000  17683.000000
# mean   ...    109.805293     64.566194     39.448001     71.441215
# std    ...     56.590689     28.557129     14.085333     32.326389
# min    ...      1.000000      1.000000      1.000000      1.000000
# 25%    ...     68.000000     45.000000     31.000000     50.000000
# 50%    ...    106.000000     63.000000     39.000000     70.000000
# 75%    ...    148.000000     82.000000     48.000000     91.000000
# max    ...    287.000000    164.000000     98.000000    183.000000
#
#           VORP_rank       %W_rank           %GS         Votes         Share  \
# count  17683.000000  17683.000000  17683.000000  17683.000000  17683.000000
# mean      42.719900     28.826613      0.369406      6.415597      0.006084
# std       12.282598     22.198109      0.454062     64.303990      0.059236
# min        1.000000      1.000000    -10.000000      0.000000      0.000000
# 25%       37.000000     10.000000      0.000000      0.000000      0.000000
# 50%       46.000000     24.000000      0.195000      0.000000      0.000000
# 75%       51.000000     44.000000      0.839500      0.000000      0.000000
# max       69.000000     98.000000      1.000000   1310.000000      1.000000
#
#            MaxVotes
# count  17683.000000
# mean    1070.038851
# std      208.777846
# min      221.000000
# 25%      980.000000
# 50%     1150.000000
# 75%     1230.000000
# max     1310.000000
#
# [8 rows x 135 columns]

# %%
df_with_votes = df[df['Share'] > 0]

# %%
df_with_votes.describe()
# Out:
#                Rk         Age           G          GS       MP_pg       FG_pg  \
# count  686.000000  686.000000  686.000000  686.000000  686.000000  686.000000
# mean   202.419825   27.488338   74.517493   68.970845   36.200729    8.150000
# std    116.055933    3.734903    9.645489   21.422255    3.098102    1.892527
# min      1.000000   19.000000   17.000000  -10.000000   21.600000    2.000000
# 25%    114.500000   25.000000   72.000000   68.000000   34.500000    6.900000
# 50%    200.500000   27.000000   78.000000   77.000000   36.600000    8.300000
# 75%    294.750000   30.000000   81.000000   81.000000   38.200000    9.500000
# max    517.000000   38.000000   82.000000   82.000000   43.700000   13.400000
#
#            FGA_pg         FG%       3P_pg      3PA_pg  ...  WS/48_rank  \
# count  686.000000  686.000000  686.000000  686.000000  ...  686.000000
# mean    16.559475    0.494496    0.774052    2.184694  ...   25.498542
# std      3.890346    0.045793    0.946402    2.446809  ...   23.039652
# min      3.700000    0.384000    0.000000    0.000000  ...    1.000000
# 25%     13.900000    0.463000    0.000000    0.100000  ...    9.000000
# 50%     16.800000    0.492000    0.300000    1.200000  ...   18.000000
# 75%     19.200000    0.522750    1.300000    3.775000  ...   34.000000
# max     27.800000    0.675000    5.300000   13.200000  ...  139.000000
#
#         OBPM_rank   DBPM_rank    BPM_rank   VORP_rank     %W_rank         %GS  \
# count  686.000000  686.000000  686.000000  686.000000  686.000000  686.000000
# mean    16.482507   28.794461   17.657434   11.596210   10.373178    0.925109
# std     12.784188   12.879340   13.216363    9.298391   10.753133    0.258376
# min      1.000000    1.000000    1.000000    1.000000    1.000000   -0.270000
# 25%      7.000000   19.000000    8.000000    4.000000    3.000000    1.000000
# 50%     13.000000   28.500000   14.000000    9.000000    7.000000    1.000000
# 75%     24.000000   38.000000   25.000000   17.000000   14.000000    1.000000
# max     73.000000   65.000000   64.000000   46.000000   73.000000    1.000000
#
#              Votes       Share     MaxVotes
# count   686.000000  686.000000   686.000000
# mean    165.374636    0.156824  1026.981050
# std     283.568755    0.258654   222.056667
# min       1.000000    0.001000   221.000000
# 25%       3.000000    0.004000   800.000000
# 50%      22.000000    0.021000  1030.000000
# 75%     182.250000    0.176750  1210.000000
# max    1310.000000    1.000000  1310.000000
#
# [8 rows x 135 columns]

# %%
df_with_votes[df_with_votes['G'] < 50]
# Out:
#         Rk            Player    Pos  Age   Tm   G  GS  MP_pg  FG_pg  FGA_pg  \
# 420    134    George Johnson     PF   24  IND  43 -10   21.6    4.2     9.2
# 423    137     Magic Johnson     SG   21  LAL  37 -10   37.1    8.4    15.9
# 3909   331      Isiah Thomas     PG   29  DET  48  46   34.5    6.0    13.9
# 3998    33        Larry Bird     SF   35  BOS  45  45   36.9    7.8    16.8
# 4448    97     Clyde Drexler     SG   30  POR  49  49   34.1    7.1    16.7
# 5330   186    Michael Jordan     SG   31  CHI  17  17   39.3    9.8    23.8
# 5453   309     Dennis Rodman     PF   33  SAS  49  26   32.0    2.8     4.9
# 5737   186     Magic Johnson     PF   36  LAL  32   9   29.9    4.3     9.2
# 6728   307    Scottie Pippen     SF   32  CHI  44  44   37.5    7.2    16.0
# 6991   131     Kevin Garnett     PF   22  MIN  47  47   37.9    8.8    19.1
# 7038   178     Allen Iverson     SG   23  PHI  48  48   41.5    9.1    22.0
# 7042   182      Mark Jackson     PG   33  IND  49  49   28.2    2.8     6.7
# 7059   199        Shawn Kemp     PF   29  CLE  42  42   35.1    6.6    13.7
# 7091   231       Karl Malone     PF   35  UTA  49  49   37.4    8.0    16.3
# 7129   269   Alonzo Mourning      C   28  MIA  46  46   38.1    7.0    13.8
# 7145   285  Shaquille O'Neal      C   26  LAL  49  49   34.8   10.4    18.1
# 7192   332    David Robinson      C   33  SAS  49  49   31.7    5.5    10.8
# 7193   333    Glenn Robinson     SF   26  MIL  47  47   33.6    7.4    16.1
# 7222   362       Steve Smith     SG   29  ATL  36  36   36.5    6.0    15.0
# 7260   400   Rasheed Wallace     PF   24  POR  49  18   28.9    4.9     9.7
# 7266   406      Chris Webber     PF   25  SAC  42  42   40.9    9.0    18.5
# 10717  305  Shaquille O'Neal      C   34  MIA  40  39   28.4    7.1    12.0
# 13032  372      Derrick Rose     PG   23  CHI  39  39   35.3    7.7    17.8
# 13100  440       Dwyane Wade     SG   30  MIA  49  49   33.2    8.5    17.1
# 17343  201      James Harden  PG-SG   31  TOT  44  43   36.6    7.8    16.7
# 17394  252      LeBron James     PG   36  LAL  45  45   33.4    9.4    18.3
#
#        ...  WS/48_rank  OBPM_rank  DBPM_rank  BPM_rank  VORP_rank  %W_rank  \
# 420    ...          59         40         30        41         39       14
# 423    ...           5          2          3         1          9        4
# 3909   ...          87         31         33        29         33       11
# 3998   ...          30         12         23        12         21        9
# 4448   ...          20         12         18         9         19        8
# 5330   ...          29         16         33        21         41       14
# 5453   ...          22         34         35        38         37        1
# 5737   ...          22         12         33        17         36       10
# 6728   ...          15         16         22        14         23        1
# 6991   ...          59         22         25        19          6       17
# 7038   ...          38         13         36        16          2        8
# 7042   ...          69         21         49        37         19        3
# 7059   ...          22         20         38        27         14       20
# 7091   ...          13         12         28        12          1        1
# 7129   ...          17         32         20        22          8        3
# 7145   ...          12          8         46        10          2        4
# 7192   ...          10         26         10        12          5        1
# 7193   ...          78         30         50        47         22        8
# 7222   ...          45         28         40        36         20        4
# 7260   ...          41         55         24        46         23        2
# 7266   ...          97         49         31        47         20       10
# 10717  ...          63         35         33        34         42       15
# 13032  ...          14          4         36         8         11        1
# 13100  ...           7          5         20         5          4        3
# 17343  ...          23          7         30        10         12       12
# 17394  ...          41         10         17         6         11       14
#
#          %GS  Votes  Share  MaxVotes
# 420   -0.233      3  0.004       690
# 423   -0.270     18  0.026       690
# 3909   0.958     11  0.011       960
# 3998   1.000      3  0.003       960
# 4448   1.000      1  0.001       980
# 5330   1.000     12  0.011      1050
# 5453   0.531      9  0.009      1050
# 5737   0.281      8  0.007      1130
# 6728   1.000     14  0.012      1160
# 6991   1.000      9  0.008      1180
# 7038   1.000    319  0.270      1180
# 7042   1.000      1  0.001      1180
# 7059   1.000      7  0.006      1180
# 7091   1.000    827  0.701      1180
# 7129   1.000    773  0.655      1180
# 7145   1.000     89  0.075      1180
# 7192   1.000      6  0.005      1180
# 7193   1.000      1  0.001      1180
# 7222   1.000      1  0.001      1180
# 7260   0.367      1  0.001      1180
# 7266   1.000     51  0.043      1180
# 10717  0.975      3  0.002      1290
# 13032  1.000      5  0.004      1210
# 13100  1.000      6  0.005      1210
# 17343  0.977      1  0.001      1010
# 17394  1.000      1  0.001      1010
#
# [26 rows x 138 columns]
